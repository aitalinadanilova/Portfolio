# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color = "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Айталина :)
#
# Спасибо за работу на проекте, за все исправления и комментарии
#
# На этапе предобработки стоит использовать больше гистограмм, чтобы оценить качество и разброс данных
#
# Подведем итоги, мы научились и повторили на проекте каким образом:
#
# + читать тех. задание проекта
# + исследовать неочищенные данные
# + выдвигать гипотезы о пропусках данных и заполнять их значениями
# + принимать решения об удалении некачественных данных
# + находить аномалии в данных и отделять редкие значения
# + соглашаться с наличием пропусков в данных и не забывать об их наличии при фильтрации
# + строить информативные визуализации
# + делить одну выборку на две части
# + находить зависимости и распределения в данных
# + формировать выводы
#
# Навыки отработаны, проект принят
#
# <b>Поздравляю с успешно сданным третьим проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Айталина :)  Спасибо за доработки проекта, мы вышли на финишную прямую, осталось поправить фильтрацию данных (потеряли около 11 000 записей) и исправить наполнение пропусков. Подсказки добавил

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Айталина :)  Стоит исправить все комментарии ❌ на проекте. Добавил подсказки и бонус
#
# Если что-то не получается, ты можешь задать вопрос преподавателю по проектам в чате «пачки» или здесь на проекте, делаю так и так, пишу такой код, не получается то и то ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Айталина :) Спасибо, что прислала задание :) Надеюсь я не ошибся, в трекере прописано
#
#         Aitalina Neustroeva (aitautau11@yandex.ru)
#
# Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название, краткое вступление в работу и главная задача зафиксированы.
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, + будет легче  идти к главной цели проекта

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <br />
#     <br />
# <font size="4", color = "black"><b> Исследование объявлений о продаже квартиры</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Выполняем предобработку данных и изучаем их, чтобы найти интересные особенности и зависимости, которые существуют на рынке недвижимости.

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
# import pandas as pd 
# data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
# data.head(10)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит делить блок загрузки библиотек и код загрузки датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Итак, в таблице 22 столбца. Тип данных в столбцах — `bool(2), float64(14), int64(3), object(3)`.
#
# Согласно документации к данным:
#
# * `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# * `balcony` — число балконов
# * `ceiling_height` — высота потолков (м)
# * `cityCenters_nearest` — расстояние до центра города (м)
# * `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# * `first_day_exposition` — дата публикации
# * `floor` — этаж
# * `floors_total` — всего этажей в доме
# * `is_apartment` — апартаменты (булев тип)
# * `kitchen_area` — площадь кухни в квадратных метрах (м²)
# * `last_price` — цена на момент снятия с публикации
# * `living_area` — жилая площадь в квадратных метрах (м²)
# * `locality_name` — название населённого пункта
# * `open_plan` — свободная планировка (булев тип)
# * `parks_around3000` — число парков в радиусе 3 км
# * `parks_nearest` — расстояние до ближайшего парка (м)
# * `ponds_around3000` — число водоёмов в радиусе 3 км
# * `ponds_nearest` — расстояние до ближайшего водоёма (м)
# * `rooms` — число комнат
# * `studio` — квартира-студия (булев тип)
# * `total_area` — общая площадь квартиры в квадратных метрах (м²)
# * `total_images` — число фотографий квартиры в объявлении

# %%
#data.hist(figsize=(15, 20))

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Убрать служ. информацию поможет точка с запятой на посл. строке кода
#
#     array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)
#
# data.hist(figsize=(15, 20));

# %%
data.hist(figsize=(15, 20));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> обзор данных проведен корректно

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> не помешает добавить вывод после первого знакомства с данными

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Вывод: на первый взгляд данные выглядят корректно, однако, как минимум по двум столбцам last_price и ceilung_height трудно сделать какой-нибудь однозначный вывод.

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Пропущенные значения в столбцах

# %%
data.isnull().sum().sort_values()
# Out:
# total_images                0
# open_plan                   0
# floor                       0
# rooms                       0
# studio                      0
# total_area                  0
# last_price                  0
# first_day_exposition        0
# locality_name              49
# floors_total               86
# living_area              1903
# kitchen_area             2278
# days_exposition          3181
# ponds_around3000         5518
# parks_around3000         5518
# cityCenters_nearest      5519
# airports_nearest         5542
# ceiling_height           9195
# balcony                 11519
# ponds_nearest           14589
# parks_nearest           15620
# is_apartment            20924
# dtype: int64

# %% [markdown]
# Количество пропущенных значений из 23699:
#
# `49` locality_name - данные не заполнены, лучше оставить пропуски;
#
# `86` floors_total - данные не заполнены, лучше оставить пропуски;
#
# `1903` living_area - данные не заполнены, лучше оставить пропуски;
#
# `2278` kitchen_area - если не указана площадь кухни, то скорее всего это студия - надо проверить. Если нет, то оставить пропуск;
#
# `3181` days_exposition - объявление не было опубликовано, оставляем пропуски;
#
# `5518` ponds_around3000 - значит прудов на расстоянии 3 км нет, оставляем пропуски;
#
# `5518` parks_around3000 - значит парков на расстоянии 3 км нет, оставляем пропуски;
#
# `5519` city_centers_nearest - центр города не близко, оставляем пропуски;
#
# `5542` airports_nearest - аэропортов рядом нет, оставляем пропуски;
#
# `9195` ceiling_height - практически в трети объявлений пропущена высота потолков, оставляем пропуски;
#
# `11519` balcony - скорее всего там нет балконов, заполняем 0;
#
# `14589` ponds_nearest - значит прудов по близости нет, оставляем пропуски;
#
# `15620` parks_nearest - значит парков по близости нет, оставляем пропуски;
#
# `20924` is_apartment - можем предположить что это не апартаменты и присвоить False.

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> По моему мнению, надо поменять вид графика.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Смена осей сделает неудобным чтение длинных надписей
#
# За поворот текста отвечает параметр rot, можно добавить обозначение оси х (процент записей с пропусками)
#
#         df.isna().mean()*100 — для расчета процента пропусков в колонке
#
# На графике мы оцениваем масштаб проблемы с пропусками и возможное совпадение % пропущенных значений в колонках

# %% [markdown]
# Заменим пропуски в столбце `balcony` , так как если  не указано количество балконов, то скорее всего их нет

# %%
data['balcony'] = data['balcony'].fillna(0)

# %% [markdown]
# Заменим пропуски в столбце `is_apartment` на `False`, скорее всего это не квартиры если не указано.

# %%
data['is_apartment'] = data['is_apartment'].fillna('False')

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Не стоит заполнять пропуски в колонке с булевыми данными — строковыми данными
#
#         data['is_apartment'] = data['is_apartment'].fillna('False')

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не совсем поняла. Тогда тут надо сначала поменять тип данных?

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         data['is_apartment'] = data['is_apartment'].fillna('False') - наполнение строковыми данными
#
#         data['is_apartment'] = data['is_apartment'].fillna(False) - наполнение булевыми данными

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Исправить
#
#         .fillna('False') - наполнение строковыми данными
#
# на
#
#         .fillna(False) - наполнение булевыми данными

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> В прошлый раз вот поменяла

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит закомментировать старый код
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Типы данных в столбцах

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Переменная `balcony` имеет тип `float64` изменим на `int64` для удобства в работе

# %%
data['balcony'] = data['balcony'].astype('int64')

# %% [markdown]
# Изменение типа `first_day_exposition` необходимо, чтобы работать с датой в дальнейшем было удобно.

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format = '%Y-%m-%d')

# %% [markdown]
# Переменная `last_price` имеет тип float64 изменим на int64 для удобства в работе

# %%
data['last_price'] = data['last_price'].astype('int64')

# %% [markdown]
# Для проверки изменений выведем еще раз информацию о датасете

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  int64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  int64
# ...

# %% [markdown]
# #### Устранение неявных дубликатов

# %%
 data['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
# ...

# %%
data['locality_name'].duplicated().sum()
# Out:
# 23334

# %% [markdown]
# Для начала приведем все к нижнему регистру:

# %%
data['locality_name'] = data['locality_name'].str.lower()

# %% [markdown]
# Затем поменяем `ё` на `е`:

# %%
data['locality_name'] = data['locality_name'].str.replace('ё', 'е')

# %% [markdown]
# Заменяем "городской поселок" на "поселок городского типа":

# %%
data['locality_name'] = data['locality_name'].str.replace('городской поселок','поселок городского типа')

# %%
data['locality_name'].sort_values().unique()
# Out:
# array(['бокситогорск', 'волосово', 'волхов', 'всеволожск', 'выборг',
#        'высоцк', 'гатчина', 'деревня агалатово', 'деревня аро',
#        'деревня батово', 'деревня бегуницы', 'деревня белогорка',
#        'деревня большая вруда', 'деревня большая пустомержа',
#        'деревня большие колпаны', 'деревня большое рейзино',
#        'деревня большой сабск', 'деревня бор', 'деревня борисова грива',
#        'деревня ваганово', 'деревня вартемяги', 'деревня вахнова кара',
#        'деревня выскатка', 'деревня гарболово', 'деревня глинка',
#        'деревня горбунки', 'деревня гостилицы', 'деревня заклинье',
#        'деревня заневка', 'деревня зимитицы', 'деревня извара',
#        'деревня иссад', 'деревня калитино', 'деревня кальтино',
#        'деревня камышовка', 'деревня каськово', 'деревня келози',
#        'деревня кипень', 'деревня кисельня', 'деревня колтуши',
#        'деревня коркино', 'деревня котлы', 'деревня кривко',
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Проверка на поиск дубликатов выполнена, молодец
#
# Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса

# %%
# check
data.locality_name.nunique()
# Out:
# 323

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />хорошая работа по избавлению от неявных дубликатов

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# + дополнительно — на рабочих проектах стоит искать дубликаты по сумме ключевых параметров (подмножеству), для примера:
#
#  + общ. площадь квартиры,
#  + этаж,
#  + общая этажность дома,
#  + расстояние до центра
#  + название населенного пункта
#  + кол-во комнат
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated

# %% [markdown]
# #### Устранение аномальных значений

# %%
data['ceiling_height'].sort_values().unique()
# Out:
# array([  1.  ,   1.2 ,   1.75,   2.  ,   2.2 ,   2.25,   2.3 ,   2.34,
#          2.4 ,   2.45,   2.46,   2.47,   2.48,   2.49,   2.5 ,   2.51,
#          2.52,   2.53,   2.54,   2.55,   2.56,   2.57,   2.58,   2.59,
#          2.6 ,   2.61,   2.62,   2.63,   2.64,   2.65,   2.66,   2.67,
#          2.68,   2.69,   2.7 ,   2.71,   2.72,   2.73,   2.74,   2.75,
#          2.76,   2.77,   2.78,   2.79,   2.8 ,   2.81,   2.82,   2.83,
#          2.84,   2.85,   2.86,   2.87,   2.88,   2.89,   2.9 ,   2.91,
#          2.92,   2.93,   2.94,   2.95,   2.96,   2.97,   2.98,   2.99,
#          3.  ,   3.01,   3.02,   3.03,   3.04,   3.05,   3.06,   3.07,
#          3.08,   3.09,   3.1 ,   3.11,   3.12,   3.13,   3.14,   3.15,
#          3.16,   3.17,   3.18,   3.2 ,   3.21,   3.22,   3.23,   3.24,
#          3.25,   3.26,   3.27,   3.28,   3.29,   3.3 ,   3.31,   3.32,
#          3.33,   3.34,   3.35,   3.36,   3.37,   3.38,   3.39,   3.4 ,
# ...

# %% [markdown]
# По сделанной выборке видим, что в столбце `ceiling_height` есть аномальные значения 20  выше метров - скорее всего пользователь забыл поставить запятую.

# %%
data['ceiling_height'] = data['ceiling_height'].where(data['ceiling_height'] < 20 , data['ceiling_height']/10)

# %%
data['ceiling_height'].sort_values().unique()
# Out:
# array([ 1.  ,  1.2 ,  1.75,  2.  ,  2.2 ,  2.25,  2.26,  2.3 ,  2.34,
#         2.4 ,  2.45,  2.46,  2.47,  2.48,  2.49,  2.5 ,  2.51,  2.52,
#         2.53,  2.54,  2.55,  2.56,  2.57,  2.58,  2.59,  2.6 ,  2.61,
#         2.62,  2.63,  2.64,  2.65,  2.66,  2.67,  2.68,  2.69,  2.7 ,
#         2.71,  2.72,  2.73,  2.74,  2.75,  2.76,  2.77,  2.78,  2.79,
#         2.8 ,  2.81,  2.82,  2.83,  2.84,  2.85,  2.86,  2.87,  2.88,
#         2.89,  2.9 ,  2.91,  2.92,  2.93,  2.94,  2.95,  2.96,  2.97,
#         2.98,  2.99,  3.  ,  3.01,  3.02,  3.03,  3.04,  3.05,  3.06,
#         3.07,  3.08,  3.09,  3.1 ,  3.11,  3.12,  3.13,  3.14,  3.15,
#         3.16,  3.17,  3.18,  3.2 ,  3.21,  3.22,  3.23,  3.24,  3.25,
#         3.26,  3.27,  3.28,  3.29,  3.3 ,  3.31,  3.32,  3.33,  3.34,
#         3.35,  3.36,  3.37,  3.38,  3.39,  3.4 ,  3.42,  3.43,  3.44,
#         3.45,  3.46,  3.47,  3.48,  3.49,  3.5 ,  3.51,  3.52,  3.53,
# ...

# %% [markdown]
# Всё-таки высота не может быть 1,75 и ниже и выше 10 м тоже какие-то нереальные значения, лучше удалить такие данные

# %% [markdown]
# #### check nan

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  int64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  int64
# ...

# %%
#data = data[(data['ceiling_height'] > 1.75) & (data['ceiling_height'] < 10)]

# %%
# check
data.shape[0]
# Out:
# 23699

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#       data = data[(data['ceiling_height'] > 1.75) & (data['ceiling_height'] < 10)]
#
# Так мы познакомились с особенностью фильтрации в библиотеке пандас, все NaN убегают вместе со значениями, которые не подходят под нашу фильтрацию, поэтому процент потери записей огромен
#
# Минус 10 000 записей
#
# стоит настроить условия фильтрации, чтобы не потерять записи с пропусками
#
# <b>алгоритм фильтрации столбца с пропусками: задаем основное условие фильтрации, + прибавляем условие не трогать записи с пропусками</b>
#
# стоит обратить внимание на весь код фильтрации, т.к. в нескольких колонках встречаются пропуски

# %%
data = data[(data['ceiling_height'] > 1.75) & (data['ceiling_height'] < 10) | (data['ceiling_height'].isna())]

# %%
data.shape[0]
# Out:
# 23693

# %%
data['ceiling_height'].unique()
# Out:
# array([2.7 ,  nan, 3.03, 2.5 , 2.67, 2.56, 3.05, 2.75, 2.6 , 2.9 , 2.8 ,
#        2.55, 3.  , 2.65, 3.2 , 2.61, 3.25, 3.45, 2.77, 2.85, 2.64, 2.57,
#        4.15, 3.5 , 3.3 , 2.71, 4.  , 2.47, 2.73, 2.84, 3.1 , 2.34, 3.4 ,
#        3.06, 2.72, 2.54, 2.51, 2.78, 2.76, 2.58, 3.7 , 2.52, 5.2 , 2.87,
#        2.66, 2.59, 2.  , 2.45, 3.6 , 2.92, 3.11, 3.13, 3.8 , 3.15, 3.55,
#        3.16, 3.62, 3.12, 2.53, 2.74, 2.96, 2.46, 5.3 , 5.  , 2.79, 2.95,
#        4.06, 2.94, 3.82, 3.54, 3.53, 2.83, 4.7 , 2.4 , 3.38, 3.01, 5.6 ,
#        3.65, 3.9 , 3.18, 3.35, 2.3 , 3.57, 2.48, 2.62, 2.82, 3.98, 2.63,
#        3.83, 3.52, 3.95, 3.75, 2.88, 3.67, 3.87, 3.66, 3.85, 3.86, 4.19,
#        3.24, 4.8 , 4.5 , 4.2 , 3.36, 3.08, 3.68, 3.07, 3.37, 3.09, 8.  ,
#        3.26, 3.34, 2.81, 3.44, 2.97, 3.14, 4.37, 2.68, 3.22, 3.27, 4.1 ,
#        2.93, 3.46, 3.47, 3.33, 3.63, 3.32, 8.3 , 2.98, 2.86, 3.17, 4.4 ,
#        3.28, 3.04, 4.45, 5.5 , 3.84, 3.23, 3.02, 3.21, 3.43, 3.78, 4.3 ,
# ...

# %% [markdown]
# #### check gap

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23693 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23693 non-null  int64
#  1   last_price            23693 non-null  int64
#  2   total_area            23693 non-null  float64
#  3   first_day_exposition  23693 non-null  datetime64[ns]
#  4   rooms                 23693 non-null  int64
#  5   ceiling_height        14498 non-null  float64
#  6   floors_total          23607 non-null  float64
#  7   living_area           21790 non-null  float64
#  8   floor                 23693 non-null  int64
#  9   is_apartment          23693 non-null  object
#  10  studio                23693 non-null  bool
#  11  open_plan             23693 non-null  bool
#  12  kitchen_area          21416 non-null  float64
#  13  balcony               23693 non-null  int64
# ...

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# стоит сменить тип данных в
#
#
#          6   floors_total                     14489 non-null  float64
#
# пропуски можно удалить, кол-во их минимально

# %%
data['floors_total'].isna().sum()
# Out:
# 86

# %%
data['floors_total'] = data['floors_total'].fillna(0)

# %%
data['floors_total'].isna().sum()
# Out:
# 0

# %%
data['floors_total'].astype('int64')
# Out:
# 0        16
# 1        11
# 2         5
# 3        14
# 4        14
#          ..
# 23694     5
# 23695     5
# 23696     3
# 23697    17
# 23698     5
# Name: floors_total, Length: 23693, dtype: int64

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23693 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23693 non-null  int64
#  1   last_price            23693 non-null  int64
#  2   total_area            23693 non-null  float64
#  3   first_day_exposition  23693 non-null  datetime64[ns]
#  4   rooms                 23693 non-null  int64
#  5   ceiling_height        14498 non-null  float64
#  6   floors_total          23693 non-null  float64
#  7   living_area           21790 non-null  float64
#  8   floor                 23693 non-null  int64
#  9   is_apartment          23693 non-null  object
#  10  studio                23693 non-null  bool
#  11  open_plan             23693 non-null  bool
#  12  kitchen_area          21416 non-null  float64
#  13  balcony               23693 non-null  int64
# ...

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Код ничего не сохраняет
#
#         data['floors_total'].astype('int64')
#
#
# стоит сменить тип данных в
#
#           6   floors_total          23693 non-null  float64

# %%
data['floors_total'] = data['floors_total'].astype('int64')

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23693 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23693 non-null  int64
#  1   last_price            23693 non-null  int64
#  2   total_area            23693 non-null  float64
#  3   first_day_exposition  23693 non-null  datetime64[ns]
#  4   rooms                 23693 non-null  int64
#  5   ceiling_height        14498 non-null  float64
#  6   floors_total          23693 non-null  int64
#  7   living_area           21790 non-null  float64
#  8   floor                 23693 non-null  int64
#  9   is_apartment          23693 non-null  object
#  10  studio                23693 non-null  bool
#  11  open_plan             23693 non-null  bool
#  12  kitchen_area          21416 non-null  float64
#  13  balcony               23693 non-null  int64
#  14  locality_name         23644 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_6376c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6376c_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_6376c_row0_col0" class="data row0 col0" >23,693.00</td>
#                         <td id="T_6376c_row0_col1" class="data row0 col1" >23,693.00</td>
# ...

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#         'rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floors_total'
#
# стоит обратить внимание на минимальные и максимальные значения в выборке и учесть наличие пропусков при фильтрации данных

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Доп. задание, на твое усмотрение — сможешь добавить в таблицу расчет медианного значения?
#
#         (
#             data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
#                   'floor', 'floors_total']]
#             .apply (['count', 'min', 'max'])
#             .style.format("{:,.2f}")
#         )

# %%
(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max', 'mean'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_7afc0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7afc0_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_7afc0_row0_col0" class="data row0 col0" >23,693.00</td>
#                         <td id="T_7afc0_row0_col1" class="data row0 col1" >23,693.00</td>
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#                 'mean' - это среднее значение

# %%
(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max', 'median'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_df9af_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_df9af_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_df9af_row0_col0" class="data row0 col0" >23,693.00</td>
#                         <td id="T_df9af_row0_col1" class="data row0 col1" >23,693.00</td>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выполнения пункта 2.4. существует два подхода
#
# Можно механически бороться с выбросами, ...
#
# основная проблема такого подхода — не учитывается неоднородность нашей выборки: у нас здесь и малые поселки, и вторая столица страны, и исторический фонд и массовая застройка, и однушки и довольно большое кол-во многокомнатных квартир, или наоборот одна две квартиры с количеством комнат больше 7-ми ...
#
#
#
# если бы у нас в таблице были бы только однокомнатные квартиры из определенного района массовой застройки, тогда да, мы бы боролись с выбросами традиционными способами, при нашем многообразии населенных пунктов, многокомнатности такие подходы не работают... т.е. они работают, но это усложнит наш проект — придется разбить и объединить записи нашей таблицы по нескольким параметрам (кол-во комнат, район, и т.д.), а затем только выполнять все остальные пункты на каждой отдельной выборке
#
# Остается другой подход — убираем редкие значения и следим за количеством потерь...
#
# Для выборки из 23-х тысяч значений, несколько записей со стоимостью квадратного метра выше 1-го млн. руб., довольно редкое явление
#
# Хороший пример, высота потолков, которую мы отрезаем по нижней и верхней планке, это скорее аномальные записи, посмотрим на другой аспект — на редкости: кол-во комнат
#
# __т.е. мы не говорим о том, что квартир с кол-ом комнат выше 7 не бывает, мы говорим, что для нашего исследования это редкие выбивающиеся из общей картины уникальные объекты, по которым необходимо проводить отдельную работу ...__
#
# подобным образом рассматриваем и остальные параметры
#
# наши помощники
#
# 1. гистограммы, с хорошим масштабом
# 2. метод describe() или облегченная версия, пример выше
# 3. метод value_counts()
#
# плюс жизненный опыт

# %%
# check

try:
    df_check = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t')
# если не получилось прочитать файл из локальной папки, то загружаем данные из сети
except:
    df_check = pd.read_csv('real_estate_data.csv', sep='\t')

# %%
# check
df_check.rooms.value_counts().to_frame()
# Out:
#     rooms
# 1    8047
# 2    7940
# 3    5814
# 4    1180
# 5     326
# 0     197
# 6     105
# 7      59
# 8      12
# 9       8
# 10      3
# 11      2
# 14      2
# 19      1
# 16      1
# 12      1
# 15      1

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры менее 20-ти и более 250-ти квадратных метров можно считать редкостями

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (0,25));

# %% [markdown]
# <div class="alert alert-dange r">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось завершить выполнение пункта 2.4 из брифа проекта
#
# 2.4.	Найдите и устраните редкие и выбивающиеся значения.
#
# __Критичный уровень потерь записей на этапе предобработки составляет 10%, оптимальный 5%__

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не поняла, что тут надо сделать?

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />В результате всех фильтраций мы должны сохранить минимум 21000 записей

# %%
(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_2e255_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2e255_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_2e255_row0_col0" class="data row0 col0" >23,693.00</td>
#                         <td id="T_2e255_row0_col1" class="data row0 col1" >23,693.00</td>
# ...

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Удалить все записи, которые содержат редкости и аномалии, например  все записи с высотой потолков выше 4-х метров

# %% [markdown]
# #### check nan

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23693 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23693 non-null  int64
#  1   last_price            23693 non-null  int64
#  2   total_area            23693 non-null  float64
#  3   first_day_exposition  23693 non-null  datetime64[ns]
#  4   rooms                 23693 non-null  int64
#  5   ceiling_height        14498 non-null  float64
#  6   floors_total          23693 non-null  int64
#  7   living_area           21790 non-null  float64
#  8   floor                 23693 non-null  int64
#  9   is_apartment          23693 non-null  object
#  10  studio                23693 non-null  bool
#  11  open_plan             23693 non-null  bool
#  12  kitchen_area          21416 non-null  float64
#  13  balcony               23693 non-null  int64
#  14  locality_name         23644 non-null  object
# ...

# %%
#data = data[data['ceiling_height'] < 4]

# %%
data.shape[0]
# Out:
# 23693

# %%
data = data[(data['ceiling_height'] < 4)|(data['ceiling_height'].isna())]

# %%
# check
data.shape[0]
# Out:
# 23604

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#     data = data[data['ceiling_height'] < 4]
#
# Так мы закрепили наше знакомство с особенностью фильтрации в библиотеке пандас, все NaN убегают вместе со значениями, которые не подходят под нашу фильтрацию, поэтому процент потери записей огромен
#
# Минус 9 000 записей
#
# стоит настроить условия фильтрации, чтобы не потерять записи с пропусками
#
# <b>алгоритм фильтрации столбца с пропусками: задаем основное условие фильтрации, + прибавляем условие не трогать записи с пропусками</b>
#
# стоит обратить внимание на весь код фильтрации, т.к. в нескольких колонках встречаются пропуски

# %%
data['ceiling_height'].describe()
# Out:
# count    14409.000000
# mean         2.717377
# std          0.249767
# min          2.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max          3.980000
# Name: ceiling_height, dtype: float64

# %%
data= data[data['floors_total'] >0]

# %%
data['floors_total'].describe()
# Out:
# count    23518.000000
# mean        10.692236
# std          6.597151
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %%
data = data[((data['total_area'] < 250) & (data['total_area'] >20))|(data['total_area'].isna())]
data['total_area'].describe()
# Out:
# count    23379.000000
# mean        58.882537
# std         28.542380
# min         20.100000
# 25%         40.000000
# 50%         52.000000
# 75%         69.000000
# max        249.900000
# Name: total_area, dtype: float64

# %%
data = data[(data['rooms'] < 7)|(data['rooms'].isna())]
data['rooms'].describe()
# Out:
# count    23329.000000
# mean         2.039307
# std          0.991194
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          6.000000
# Name: rooms, dtype: float64

# %%
data = data[data['last_price'] != 12190.00 ]
data['last_price'].describe()
# Out:
# count    2.332800e+04
# mean     6.117142e+06
# std      6.810350e+06
# min      4.300000e+05
# 25%      3.400000e+06
# 50%      4.600000e+06
# 75%      6.700000e+06
# max      3.300000e+08
# Name: last_price, dtype: float64

# %%
data['last_price'].hist(bins=100, range = (15000000, 100000000), figsize = (10,5))
# Out:
# <AxesSubplot:>

# %%
data = data[(data['last_price'] < 15000000)|(data['last_price'].isna())]
data['last_price'].describe()
# Out:
# count    2.226800e+04
# mean     5.135383e+06
# std      2.670172e+06
# min      4.300000e+05
# 25%      3.370000e+06
# 50%      4.500000e+06
# 75%      6.290000e+06
# max      1.500000e+07
# Name: last_price, dtype: float64

# %%
data['living_area'].hist(bins = 50, figsize = (10,5), range = (0, 14))
# Out:
# <AxesSubplot:>

# %%
data = data[(data['living_area'] > 14)| (data['living_area'].isna())]

# %%
# check
data.shape[0]
# Out:
# 21852

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#     data = data[data['living_area'] > 14]
#
#
#
# Минус 1 000 записей
#
# стоит настроить условия фильтрации, чтобы не потерять записи с пропусками
#
# <b>алгоритм фильтрации столбца с пропусками: задаем основное условие фильтрации, + прибавляем условие не трогать записи с пропусками</b>
#
# стоит обратить внимание на весь код фильтрации, т.к. в нескольких колонках встречаются пропуски

# %%
data['living_area'].hist(bins = 70, figsize = (10,5), range = (100, 160))
# Out:
# <AxesSubplot:>

# %%
data = data[(data['living_area'] < 100)|(data['living_area'].isna())]

# %%
data['days_exposition'].hist(bins = 50)
# Out:
# <AxesSubplot:>

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.0012, 0.01, .5, .99, .9988]) # выбираем размах в 0,9976 квантилей 
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_182ff_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_182ff_level0_row0" class="row_heading level0 row0" >0.0012</th>
#                         <td id="T_182ff_row0_col0" class="data row0 col0" >0.00</td>
#                         <td id="T_182ff_row0_col1" class="data row0 col1" >22.20</td>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Квантили что это такое
#
# https://fin-accounting.ru/cfa/l1/quantitative/cfa-quartiles-quintiles-deciles-percentiles?ysclid=l7gy2kky4i156375632
#
# они помогают увидеть редкости и аномалии в данных

# %%
# check
(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_c21d4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c21d4_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_c21d4_row0_col0" class="data row0 col0" >21,794.00</td>
#                         <td id="T_c21d4_row0_col1" class="data row0 col1" >21,794.00</td>
# ...

# %%
# check
data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5));

data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5))
plt.ylim(0, 40);

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#           'days_exposition',  'kitchen_area', 'floors_total'
#
# для определения хвостов, редкостей и аномалий смотрим на минимальные и максимальные значения, строим несколько гистограмм по каждому параметру
#
# например в таблице мы видим аномалию квартиру в здании из 60-ти этажей (можно посмотреть, где такое здание находится), а на гистограмме аномальную скорость продаж в один или два дня
#
# стоит учесть наличие пропусков при фильтрации данных, их не стоит терять и сохранить для исследования минимум 21000 записей

# %% [markdown]
# > Согласно графика видно, что продажи за 1, 2 дня редкое событие. Можно исключить такие данные.

# %%
data.shape[0]
# Out:
# 21794

# %%
data['days_exposition'].describe()
# Out:
# count    19048.000000
# mean       176.260762
# std        215.180368
# min          1.000000
# 25%         44.000000
# 50%         93.000000
# 75%        224.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
data = data[(data['days_exposition'] > 2)|(data['days_exposition'].isna())]

# %%
data.shape[0]
# Out:
# 21790

# %%
data['kitchen_area'].hist(bins = 100, figsize = (10,5), range = (0,60))
# Out:
# <AxesSubplot:>

# %%
data['kitchen_area'].hist(bins = 100, figsize = (10,5), range = (0,10))
# Out:
# <AxesSubplot:>

# %%
data['kitchen_area'].hist(bins = 100, figsize = (10,5), range = (0,5))
# Out:
# <AxesSubplot:>

# %%
data.hist(column = 'kitchen_area', bins = 50, figsize = (15,3), range = (0,5))
plt.ylim(0, 50);

# %%
data = data[(data['days_exposition'] > 4)|(data['days_exposition'].isna())]

# %%
data.shape[0]
# Out:
# 21476

# %%
data['floors_total'].hist(bins = 50, figsize =(10,5))
# Out:
# <AxesSubplot:>

# %%
data['floors_total'].describe()
# Out:
# count    21476.000000
# mean        10.718756
# std          6.601179
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %%
data.hist(column = 'floors_total', bins = 50, figsize = (15,3), range = (40,60))
plt.ylim(0, 5);

# %% [markdown]
# > В 60-ти этажном здании продается только одна квартира.

# %%
data[data['floors_total']==60].pivot_table(index='locality_name', values = 'floors_total')
# Out:
#                floors_total
# locality_name
# кронштадт                60

# %%
data = data[(data['floors_total'] < 60)|(data['floors_total'].isna())]

# %%
data['floors_total'].describe()
# Out:
# count    21475.000000
# mean        10.716461
# std          6.592761
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         36.000000
# Name: floors_total, dtype: float64

# %%
data.shape[0]
# Out:
# 21475

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_d6ff6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d6ff6_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_d6ff6_row0_col0" class="data row0 col0" >21,475.00</td>
#                         <td id="T_d6ff6_row0_col1" class="data row0 col1" >21,475.00</td>
# ...

# %%
# check
data.hist(column = 'kitchen_area', bins = 50, figsize = (15,3), range = (0,5));

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Остались редкие кухни

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# Добавляем столбец с ценой одного квадратного метра - `metr_price` :

# %%
data['metr_price'] = data['last_price'] / data['total_area']

# %% [markdown]
# Добавляем столбец с днями недели публикации объявления - `weekday`:

# %%
data['weekday'] = data['first_day_exposition'].dt.weekday

# %% [markdown]
# Добавляем столбец с месяцами публикации объявления - `month`:

# %%
data['month'] = data['first_day_exposition'].dt.month

# %% [markdown]
# Добавляем столбец с месяцами публикации объявления - `year`:

# %%
data['year'] = data['first_day_exposition'].dt.year

# %% [markdown]
# Добавляем столбцы с типом этажа квартиры (значения — «‎первый», «последний», «другой»):

# %%
def floor_group(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'
data['floor_type'] = data.apply(floor_group, axis=1)

# %% [markdown]
# Добавляем столбцы с расстоянием до центра города в километрах - `from_center` (переводим из м в км и округляем до целых значений):

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Функция хорошая, стоит учесть крайние условия: нулевые и отрицательные значения

# %%
data['from_center'] = (data['cityCenters_nearest']/1000).round()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> данные добавлены корректно, молодец

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Изучение параметров объектов.

# %% [markdown]
# ##### общая площадь - `total_area`:

# %%
data['total_area'].hist(bins=100, range=(10,200), figsize=(10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# >Вывод: судя по гистограмме чаще всего продаются квартиры с площадью примерно от 30 кв.м до 45 кв.м - скорее всего это квартиры-студии и однокомнатные. Также можем отметить, что чем больше площадь, тем меньше объявлений о продаже.

# %% [markdown]
# ##### жилая площадь - `living_area`:

# %%
data['living_area'].hist(bins=100, range=(10,200), figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
data['living_area'].sort_values().head(10)
# Out:
# 2320     14.01
# 3912     14.02
# 17329    14.02
# 6926     14.03
# 3332     14.06
# 18765    14.08
# 21366    14.10
# 13795    14.10
# 3988     14.10
# 14119    14.10
# Name: living_area, dtype: float64

# %% [markdown]
# >Судя по гистограмме чаще всего продаются квартиры с жилой площадью менее 25 кв.м. - что, кажется немного странным.

# %% [markdown]
# ##### площадь кухни - `kitchen_area`

# %%
data['kitchen_area'].hist(bins=50, range=(0,30), figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
data['kitchen_area'].sort_values().head(10)
# Out:
# 20217    1.30
# 906      2.00
# 6262     2.00
# 11033    2.00
# 9138     2.00
# 16367    2.00
# 17834    2.30
# 7950     2.89
# 2165     3.00
# 17424    3.00
# Name: kitchen_area, dtype: float64

# %% [markdown]
# >Больше всего размещено объявлений с маленькой кухней - скорее всего это квартиры-студии.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Хорошие графики
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://pyprog.pro/mpl/mpl_axis_signatures.html) и [там](https://pyprog.pro/mpl/mpl_title.html), и
#
# [тут](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %% [markdown]
# ##### цена объекта - `last_price`:

# %%
data['last_price'].hist(bins=50, range=(0,20000000), figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
data['last_price'].sort_values().head(10)
# Out:
# 14911    430000
# 17456    430000
# 16274    440000
# 17676    450000
# 5698     450000
# 16219    450000
# 9581     450000
# 23484    470000
# 21912    470000
# 18867    470000
# Name: last_price, dtype: int64

# %%
data['last_price'].sort_values(ascending=False).head(10)
# Out:
# 19166    14999999
# 5459     14999000
# 13171    14998000
# 17992    14990000
# 19084    14990000
# 6628     14990000
# 13335    14990000
# 10978    14990000
# 9346     14970000
# 16572    14950000
# Name: last_price, dtype: int64

# %% [markdown]
# >Больше всего объявлений со стоимостью - 450000. Наименьшая стоимость квартир - 12190, наибольшая - 420000000.

# %% [markdown]
# ##### количество комнат - `rooms`:

# %%
data['rooms'].hist(bins=20, range=(1,7), figsize=(10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# >Больше всего объявлений о продаже 2-х комнатных квартир.

# %% [markdown]
# ##### высота потолков - `ceiling_height`

# %%
data['ceiling_height'].hist(bins=50, range=(1,6), figsize=(10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# > Больше всех объявлений о продаже квартир с высотой примерно 2,5 м.

# %% [markdown]
# ##### этаж квартиры - `floor`

# %%
data['floor'].unique()
# Out:
# array([ 8,  1,  4, 13,  5, 22, 26,  7,  3,  2, 11, 15,  9, 18,  6, 10, 19,
#        16, 20, 27, 17, 14, 12, 28, 24, 21, 25, 23, 30, 29, 32, 33, 31])

# %%
data['floor'].hist(bins=30, range=(1,30), figsize=(10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# >Больше всего объявлений с квартирами на этажах с 1-го по 5-ый.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас трудно определить границу резкого снижения кол-ва объявлений, или на 4-ке, или на 5-ке, или на 6-ке ...

# %%
data['floor'].hist(bins=100, range=(1,30), figsize=(10,5))
plt.xlabel('Количество этажей')
plt.ylabel('Количество объявлений')
# Out:
# Text(0, 0.5, 'Количество объявлений')

# %% [markdown]
# ##### тип этажа квартиры («первый», «последний», «другой»):

# %%
data['floor_type'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### общее количество этажей в доме - `floors_total`

# %%
data['floors_total'].hist(bins= 10)
# Out:
# <AxesSubplot:>

# %% [markdown]
# >Больше всего квартир продается в 5-ти этажных домах.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас  трудно определить типовую высотность зданий

# %%
data['floors_total'].hist(bins= 70, range=(1,30), figsize=(10,5))
plt.xlabel('Количество этажей')
plt.ylabel('Количество объявлений')
# Out:
# Text(0, 0.5, 'Количество объявлений')

# %% [markdown]
# ##### расстояние до центра города в метрах - `cityCenters_nearest`:

# %%
data['cityCenters_nearest'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# >Чаще всего продают квартиры находящиеся на расстоянии менее 20км от центра города.

# %% [markdown]
# ##### расстояние до ближайшего аэропорта - `airports_nearest`:

# %%
data['airports_nearest'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# >Судя по гистограмме можно сказать, что рядом с аэропортом продается не так много квартир, хотя их может прото не быть.

# %% [markdown]
# ##### расстояние до ближайшего парка - `parks_nearest`:

# %%
data['parks_nearest'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# > Можно сказать, что очень много квартир продается возле парков, или скорее всего парков в городе достаточно много.

# %% [markdown]
# ##### день и месяц публикации объявления - `weekday`, `month`:

# %%
data['weekday'].hist(range =(1,7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы
#
#         range =(1,7)
#
# кодировка дней недели начинается с 0

# %%
data['weekday'].hist(bins = 50, range =(0,6), figsize=(10,5))
plt.xlabel('День недели')
plt.ylabel('Количество объявлений')
# Out:
# Text(0, 0.5, 'Количество объявлений')

# %%
data['month'].hist(range =(1,12))
# Out:
# <AxesSubplot:>

# %% [markdown]
# > Можно сделать вывод, что на выходных в летние месяцы пользователи редко публикуют объявления. Оказывается больше всего объявлений пуюликуется в начале года.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас может показаться, что в декабре и январе публикуют самое большое кол-во объявлений

# %%
data['month'].hist(bins = 50, range =(1,12), figsize=(10,5))
plt.xlabel('Месяц')
plt.ylabel('Количество объявлений')
# Out:
# Text(0, 0.5, 'Количество объявлений')

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Вывод: после правки функций, можно сказать, что больше всего объявлений публикуется в начале феврале и марте и по средам.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️  Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Интересно, почему февраль (самый короткий месяц) опережает все месяцы — ?__

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Так как в феврале меньше всего дней - соответственно конверсия больше у данного месяца

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Это количество объявлений в месяц, если дней меньше, то сумма объявлений должна быть меньше
#
# Стоит смотреть на цифры и графики
#
# Можно посмотреть на каждый февраль из нашей выборки, а затем на каждый день особого февраля ...

# %% [markdown]
# #### Скорость продажи квартир.

# %%
data['days_exposition'].hist(bins=30, figsize = (10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Посчитаем медиану:

# %%
data['days_exposition'].median()
# Out:
# 95.0

# %% [markdown]
# Посчитаем среднее значение:

# %%
data['days_exposition'].mean()
# Out:
# 179.19445779272786

# %%
data['days_exposition'].describe()
# Out:
# count    18729.000000
# mean       179.194458
# std        215.814568
# min          5.000000
# 25%         45.000000
# 50%         95.000000
# 75%        228.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# >Самые быстрая продажа квартир происходит за 1 день, а самая долгая - более 10 месяцев. В среднем квартиры продают за 187 дней.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />После фильтрации данных: самые быстрые продажи квартир происходит за 5 дней, а самая долгая - более 10 месяцев. В среднем квартиры продают за 179 дней

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит пересчитать статистики скорости продажи после восстановления пропусков

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#
# __Интересно посмотреть на изменение средней  скорости продаж по годам__

# %%
(
    data
    .pivot_table(index='year', values='days_exposition', aggfunc='mean')
    .plot(kind='bar', grid=True, figsize=(10,5))
)
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Не исследованы моды в 'days_exposition' и как они влияют на скорость продажи, подсказка на что смотреть
#
# [Условия размещения объявлений](https://yandex.ru/support/realty/owner/home/add-ads-housing.html)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Не совсем поняла как исследовать моды. В Москве и Санкт-Петербурге и их областях бесплатное объяыление может висеть 182 дня. В других же регионах срок публикации зависит от цены.

# %%
# check
# Моды на реальных данных
    
df_check['days_exposition'].value_counts().to_frame().head(20).plot(kind = 'barh', figsize = (15,6), rot = 0);

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Моды на реальных данных
#
#         Мода (Mo) представляет собой значение изучаемого признака, повторяющееся с наибольшей частотой, т.е. мода – значение признака, встречающееся чаще всего. Медианой (Me) называется значение признака, приходящееся на середину ранжированной (упорядоченной) совокупности, т.е. медиана – центральное значение вариационного ряда.
#
# Выделяются моды на 45 и 60 дней, а значения на 44 и 45 дней, явно имеет техническую причину снятия, из-за формата числа
#
# В нашем проекте — моды, из-за подозрения что это техническое снятие с продаж, могут искажать реальный расчет скорости продажи квартиры
#
# полностью из проекта удалять их не стоит, можно временно исключить из расчета скорости продаж

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Для определения быстрых и долгих продаж оптимальнее ориентироваться на 25-тый и 75-тый квантили

# %% [markdown]
# #### Влияние факторов на общую (полную) стоимость объекта.

# %% [markdown]
# ##### Зависимость стоимости от общей площади

# %%
(
    data.pivot_table(index='total_area', values='last_price')
    .plot(grid=True, style='o', figsize=(10, 5))
)
# Out:
# <AxesSubplot:xlabel='total_area'>

# %%
data['total_area'].corr(data['last_price'])
# Out:
# 0.7402307941242711

# %% [markdown]
# >Корреляция в `0.71` показывает, что зависимость стоимости от общей площади есть, но не такая большая. Согласно графика видно, что чем больше площадь квартиры тем больше стоимость квартиры.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />  Можно попробовать настроить вид точечных графиков
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)
#
# Примеры расчета коэф. корреляции и не только
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?ysclid=l9ev0utyg728177057)

# %% [markdown]
# ##### Зависимость стоимости от жилой площади

# %%
(
    data.pivot_table(index='living_area', values='last_price')
    .plot(grid=True, style='o', figsize=(10, 5))
)
# Out:
# <AxesSubplot:xlabel='living_area'>

# %%
data['living_area'].corr(data['last_price'])
# Out:
# 0.6244988064376594

# %% [markdown]
# >Корреляция в `0.61` показывает, что зависимость стоимости от жилой площади также есть, но тоже не такая большая.

# %% [markdown]
# ##### Зависимость стоимости от площади кухни

# %%
(
    data.pivot_table(index='kitchen_area', values='last_price')
    .plot(grid=True, style='o', figsize=(10, 5))
)
# Out:
# <AxesSubplot:xlabel='kitchen_area'>

# %%
data['kitchen_area'].corr(data['last_price'])
# Out:
# 0.5435146428224273

# %% [markdown]
# >Тут зависимость еще меньше.

# %% [markdown]
# ##### Зависимость стоимости от количества комнат в квартире

# %%
(
    data.pivot_table(index='rooms', values='last_price')
    .plot(grid=True, style='o-', figsize=(10, 5))
)
# Out:
# <AxesSubplot:xlabel='rooms'>

# %%
data['rooms'].corr(data['last_price'])
# Out:
# 0.4735790655017706

# %% [markdown]
# >Корреляция `0,4`- зависимость небольшая, но согласно графика видим, что дороже всех оказалась 12-ти комнатная квартира.

# %% [markdown]
# ##### Зависимость стоимости от типа этажа

# %%
(
    data.pivot_table(index='floor_type', values='last_price')
    .plot(grid=True, style='o-', figsize=(10, 5))
)
# Out:
# <AxesSubplot:xlabel='floor_type'>

# %% [markdown]
# > Как и ожидалось дешевле всех квартиры, расположенные на первых этажах.

# %% [markdown]
# ##### Зависимость стоимость от даты размещения (день недели, месяц, год).

# %%
(
    data.pivot_table(index='weekday', values='last_price')
    .plot(grid=True, style='o-', figsize=(10, 5))
)
(
    data.pivot_table(index='month', values='last_price')
    .plot(grid=True, style='o-', figsize=(10, 5))
)
(
    data.pivot_table(index='year', values='last_price')
    .plot(grid=True, style='o-', figsize=(10, 5))
)
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# > Дороже всего квартиры, опубликованные во вторник, дешевле всего - в субботу.
# Дороже всего квартиры, продающиеся в апреле года, дешевле всего - в июне.
# Квартиры дороже всего были в 2014 года, затем до 2018 был спад цен, однако с 2019 года цены на квартиры дорожают.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для решения задачи
#
#           Стоит дополнить  вывод об изменении цен по годам, необходимо учесть другие факторы, которые также изменяются с годами: площадь и кол-во объявлений о продаже (стоит добавить или графики, или сводные таблицы и исследовать взаимное влияние параметров)
#
# берем твой код
#
#         (
#             data.pivot_table(index='year', values='last_price')
#             .plot(grid=True, style='o-', figsize=(10, 5))
#         )
#
# для первой таблицы стоит   в параметре values='last_price' заменить цену на общую площадь
#
# для второй таблицы делаем все тоже самое, но вместо подсчета среднего значения, подсчитываем кол-во объявлений
#
# затем берем три графика или таблицы вместе и находим причину падения средних цен с 2014 по 2019 год

# %%
(
        data.pivot_table(index='year', values='total_area')
        .plot(grid=True, style='o-', figsize=(10, 5))
    )
# Out:
# <AxesSubplot:xlabel='year'>

# %%
(
        data.pivot_table(index='year',values ='total_area',  aggfunc='count')
        .plot(grid=True, style='o-', figsize=(10, 5))
    )
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> С годами площадь продаваемых квартир становится всё меньше и меньше, скорее всего это из-за популярности квратир-студий. Также стоит обратить внимание, что в 2018 году было размещено наибольшее количество объявлений оо продаже квартир.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Направление мысли правильное, стоит поправить акценты вывода (доп. исследования на твое усмотрение)
#
# Если смотреть только на изменение цены по годам мы можем сделать некорректный вывод, что цены падали, а на самом деле цена это параметр на который влияет несколько других факторов, по этой причине можно посмотреть на основные из них:
#
# + изменение кол-ва записей — принять решение о достаточности данных для анализа и сравнения (сравнивать 100 объявлений и 8000, а возможно, что они еще и из разных локаций, не совсем корректно)
# + изменение площади, как основного параметра от которого зависит стоимость квартиры, в 2017-2018 гг. на сервис или рынок ИТ-торговли недвижимостью пришел массовый продавец, и средние значения упали ..., а за ней и цена
# + изменение кол-ва поданных объявлений из разных локаций, т.к. есть питерские квартиры, а есть выборгские квартиры и стоят они по разному, и в разные годы могло быть больше квартир из определенной локации
# + полнота периода для анализа, 2014 и 2019 гг. неполные, а у нас есть сезонные колебания цен, например летнее снижение цен
# + изменение доли дорогих категорий в общей выборке (средние этажи)
#
# и т.д.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить  вывод об изменении цен по годам, необходимо учесть другие факторы, которые также изменяются с годами: площадь и кол-во объявлений о продаже (стоит добавить или графики, или сводные таблицы и исследовать взаимное влияние параметров: кол-во записей и изменение средней цены и средней площади в течение лет)

# %% [markdown]
# #### Расчет средней цены одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений.

# %%
ten_city = (data
         .pivot_table(index='locality_name', 
                      aggfunc={'last_price':'count', 'metr_price':'mean'})
         .sort_values(by='last_price', ascending=False)
        ).head(10)
ten_city
# Out:
#                    last_price     metr_price
# locality_name
# санкт-петербург         13876  106933.333004
# поселок мурино            506   85276.898365
# поселок шушары            415   77662.991227
# всеволожск                380   67174.093474
# пушкин                    335  100246.098288
# колпино                   327   75203.698427
# гатчина                   297   69158.892737
# поселок парголово         291   89413.104505
# деревня кудрово           284   92315.881776
# выборг                    227   57827.912861

# %% [markdown]
# >Самая большая цена за квадратный метр в Санкт-Петербурге, а сама маленькая цена во Всеволжске.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />ТОП-10 рассчитан корректно

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Недостаточно найти числа, стоит их показать красиво, удобно и наглядно, чтобы одного взгляда хватило, где самые самые, а где подешевле 📊

# %%
 (
    ten_city
    .sort_values(by='metr_price', ascending=False)['metr_price']
    .plot(figsize=(15,5), kind='bar')
 )
# Out:
# <AxesSubplot:xlabel='locality_name'>

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в3</b></font>
# <br />
# <font size="3", color = "black">
# <br />      Можно развернуть график, чтобы не поворачивать голову, когда читаешь
#
#      kind='barh'

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# ##### Зависимость стоимости объекта от расстояния до центра города в Санкт-Петербурге.

# %%
#data['center_km_spb'] = data['cityCenters_nearest'] / 1000
#data['center_km_spb'] = data['center_km'].fillna(0).astype(int)
#(
#    data.query('locality_name == "санкт-петербург"')
#    .pivot_table(index='center_km_spb', values='last_price')
#    .plot(kind='bar', grid=True, figsize=(10,5))
#)

# %% [markdown]
# >Конечно же, стоимость увеличивается с уменьшением расстояния центра города намного дороже остальной части города.Но почему-то на расстоянии 27 км от центра города цена опять увеличивается.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит поправить переменные
#
#         data['center_km_spb'] = data['cityCenters_nearest'] / 1000
#         data['center_km_spb'] = data['center_km'].fillna(0).astype(int)

# %%
(
    data[data['locality_name']=='санкт-петербург']
    .pivot_table(index='from_center', values='last_price', aggfunc='mean')
    .plot(kind='bar', grid=True, figsize=(10,5))
)
# Out:
# <AxesSubplot:xlabel='from_center'>

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит изучить записи, которые привели к выбросу на 27-м км.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит посмотреть на количество квартир разных категорий (первый, последний, другой), которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />    Для решения задачи
#
#     Стоит посмотреть на количество квартир разных категорий (первый, последний, другой), которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре
#
# стоит выполнить группировку данных на питерских квартирах

# %%
data['cityCenters_nearest'] = (data['cityCenters_nearest']/1000).round()
spb = (data[data['locality_name']=='санкт-петербург']
         .pivot_table(index={'cityCenters_nearest','floor_type' },
                      values = 'from_center',
                     aggfunc = 'count')
         .sort_values(by='cityCenters_nearest')
        ).head(20)
spb
# Out:
#                                 from_center
# floor_type cityCenters_nearest
# другой     0.0                            7
# последний  0.0                            2
# первый     0.0                            2
# другой     1.0                           71
# последний  1.0                           35
# первый     1.0                           14
# другой     2.0                          107
# последний  2.0                           56
# первый     2.0                           38
# другой     3.0                          160
# последний  3.0                           63
# первый     3.0                           47
# последний  4.0                           83
# первый     4.0                           72
# другой     4.0                          362
# первый     5.0                           68
# другой     5.0                          484
# последний  5.0                           93
# первый     6.0                           56
# другой     6.0                          326

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Две стопки монет: в одной 8 золотых и 2 серебряные, во второй 6 золотых и 4 серебряные. В какой стопке средняя цена одной монеты будет дороже?
#
# Размер доли категорий квартир с более дешевой стоимостью намного больше на 3-м километре, чем на пятом, что является одной из причин падения и пика...
#
# возможно к этому фактору добавляются и другие

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Для решения задачи
#
#         Стоит изучить записи, которые привели к выбросу на 27-м км., у нас аномалии на питерских квартирах ..
#
# стоит выполнить фильтрацию данных: оставить только питерские квартиры и только с 27-го километра

# %%
(
    data[(data['locality_name']=='санкт-петербург')& (data['from_center']>=27)]
    .pivot_table(index={'cityCenters_nearest','floor_type' },
                      values = 'from_center',
                     aggfunc = 'count')
)
# Out:
#                                 from_center
# floor_type cityCenters_nearest
# другой     27.0                           1
#            28.0                           4
#            29.0                           1
# первый     28.0                           2
#            29.0                           4
# последний  27.0                           1
#            28.0                           1
#            29.0                           1

# %% [markdown]
# > В Санкт-Петербурге на расстоянии более 27 км от центра было мадл объявлений о продаеж-скорее всего эти квартиры продавались в городе Пушкин. Поэтому в гистограмме зависимости стоимости объекта от расстояния до центра города в Санкт-Петербурге возник выброс.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принимается, кол-во наблюдений важный параметр для оценки качества данных
#
# у нас всего 2 записи на 27-м км., одна из которых с аномальной ценой, по этой причине мы отвергаем данное наблюдение

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# <b> Согласно проведенного анализа можно сделать вывод, что чаще всего продаются 1-2х комнантные квартиры.  Наиболее дорогие квартиры продаются в центре города.  И оказывается в большинстве случаев квартиры продаются за один день!  На стоимость больше влияет площадь квартиры, а не число комнат.  Ниже всех цена на квартиры, которые распологаются на первых этажах.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Технически вывод хороший, есть сравнения показателей, инсайты, анализ рынка недвижимости, молодец
#
# Осталось перепроверить итоговый вывод после исправления всех комментариев

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# например можно посмотреть сколько стоит кв. метр в питерской трешке и сколько стоит в однушке — выполнение этого примечания на твое усмотрение

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Самые дорогие варианты квартир находятся в центре города, однако в центре также есть и достаточно дешёвые варианты.
#
# Первый этаж непосредственно влияет на стоимость квартиры - в среднем квартиры на 1-м этаже значительно дешевле. Чуть дороже последний этаж. Наибольшая стоимость у квартир, расположенных не на 1-м и не на последнем этаже.
#
# Цена за квадрат выше у однокомнатных квартир и квартир с 4 и 5 комнатами. Последнее, вероятно, объясняется элитностью недвижимости.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнила исследовательскую работу, молодец
#
# Критические ❌ комментарии
#
#
# + сменить тип данных
# + настроить фильтрацию редких значений в п. 2.4
# + подправить гистограммы в п.4.1
# + добавить вывод в п. 4.3
# + добавить график в ТОП-10
# + поправить выполнение и исследовать аномалии в п.4.5
# + поправить итоговый вывод
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)
#
# <p> Доп. материал: методы группировки и расчета суммы, средних и т.д.
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
#  Интересная функция в библиотеке пандаса
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)
#
# [Как выбрать определенные столбцы из DataFrame](https://dfedorov.spb.ru/pandas/03.%20%D0%9A%D0%B0%D0%BA%20%D0%B2%D1%8B%D0%B1%D1%80%D0%B0%D1%82%D1%8C%20%D0%BF%D0%BE%D0%B4%D0%BC%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2%D0%BE%20%D0%B8%D0%B7%20DataFrame_.html?ysclid=l9sps5lt6g576766938)
#
# [How to visualise data using histograms in Pandas](https://practicaldatascience.co.uk/data-science/how-to-visualise-data-using-histograms-in-pandas)

# %% [markdown]
# ### Бонус

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />Диаграмма рассеяния

# %%
# check
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# check
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']])
plt.gcf().set_size_inches(12,12);

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена трешки')


data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='living_area', alpha=0.5, figsize=(15,8), c = 'r', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');

# %%
# check
price_pivot_area = data.pivot_table(index='last_price', values=([
    'total_area', 'living_area', 'kitchen_area']), aggfunc='median')
price_pivot_area = price_pivot_area.reset_index()
# Посмотрим на диаграммы рассеяния для столбцов 'total_area', 'living_area', 'kitchen_area'.
for row in ['total_area', 'living_area', 'kitchen_area']:
    sns.relplot(data=price_pivot_area, x='last_price', y=row, kind='scatter')

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='living_area' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'g', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — Жилая');

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
