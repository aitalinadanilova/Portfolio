# %% [markdown]
# # Дашборд медицинских данных
# **Описание проекта:**  данные официальной медицинской статистики в настоящий момент находятся в неудобном для восприятия формате. Медикам приходится или тратить много времени на их анализ, или отказаться от их использования.
#
# **Цель исследования:** целью проекта является демонстрация иных, качественно новых, возможностей работы с данными медицинской статистики, и это не вопрос праздного любопытства.
#
# **Ход исследования:**
# 1. Загрузка данных
# 2. Изучение таблиц, переформатирование: ○ изменение порядка строк и столбцов;
# - переименование колонок;изменение типа данных;
# - удаление колонок;
# - дополнительные манипуляции;
# 3. Создание плана визуализации DataLens.
# 4. Построение дашборда DataLens.
#
# **Описание данных:** данные взяты из двух официальных книг:
# - Состояние онкологической помощи населению России в 2021 году
# - Злокачественные новообразования в России в 2021 году

# %% [markdown]
# ## Загрузка данных

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings

# %matplotlib inline

# %%
warnings.filterwarnings('ignore')

# %%
table9 = pd.read_excel('/datasets/2021_Таблица_009.xlsx', header = [3], decimal=',')
table9 = table9.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)
table9.head()
# Out:
#          Локализация, нозологическая форма  Unnamed: 1 Код МКБ 10  \
# 0                                      NaN         NaN        NaN
# 1  Злокачественные новообразования - всего         NaN     С00-96
# 2                                     Губа         NaN        С00
# 3                                     Язык         NaN     С01.02
# 4                   Большие слюнные железы         NaN     С07.08
#
#    Станд. пока- затель  Ошиб. станд. показ.                  Показа- тель  \
# 0                  NaN                  NaN                           NaN
# 1               224.87                 0.32  Абс.число\n"Грубый" Уд.вес.%
# 2                 0.65                 0.02  Абс.число\n"Грубый" Уд.вес.%
# 3                 1.38                 0.02  Абс.число\n"Грубый" Уд.вес.%
# 4                 0.49                 0.02  Абс.число\n"Грубый" Уд.вес.%
#
#                   Возраст           Unnamed: 7         Unnamed: 8  \
# ...

# %%
#выведем названия колонок
list(table9)
# Out:
# ['Локализация, нозологическая форма',
#  'Unnamed: 1',
#  'Код МКБ 10',
#  'Станд. пока- затель',
#  'Ошиб. станд. показ.',
#  'Показа- тель',
#  'Возраст',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24']

# %%
table9['Unnamed: 1'].unique()
# Out:
# array([nan])

# %%
#можем удалить столбец
table9.drop('Unnamed: 1', axis= 1 , inplace= True)
table9.head()
# Out:
#          Локализация, нозологическая форма Код МКБ 10  Станд. пока- затель  \
# 0                                      NaN        NaN                  NaN
# 1  Злокачественные новообразования - всего     С00-96               224.87
# 2                                     Губа        С00                 0.65
# 3                                     Язык     С01.02                 1.38
# 4                   Большие слюнные железы     С07.08                 0.49
#
#    Ошиб. станд. показ.                  Показа- тель                 Возраст  \
# 0                  NaN                           NaN                   Всего
# 1                 0.32  Абс.число\n"Грубый" Уд.вес.%  580415\n397.91\n100.00
# 2                 0.02  Абс.число\n"Грубый" Уд.вес.%        1902\n1.30\n0.33
# 3                 0.02  Абс.число\n"Грубый" Уд.вес.%        3335\n2.29\n0.57
# 4                 0.02  Абс.число\n"Грубый" Уд.вес.%        1213\n0.83\n0.21
#
# ...

# %%
#переименуем столбцы
table9 = table9.rename(
    columns = {
    'Локализация, нозологическая форма':'локализация',
    'Код МКБ 10':'код мкб 10',
    'Станд. пока- затель':'стандартный показатель',
    'Ошиб. станд. показ.':'ошибочно-стандартный показатель',
    'Показа- тель':'показатель',
    'Возраст':'всего',
    'Unnamed: 7':'возраст от 0 до 4',
    'Unnamed: 8':'возраст от 5 до 9',
    'Unnamed: 9':'возраст от 10 до 14',
    'Unnamed: 10':'возраст от 15 до 19',
    'Unnamed: 11':'возраст от 20 до 24',
    'Unnamed: 12':'возраст от 25 до 29',
    'Unnamed: 13':'возраст от 30 до 34',
    'Unnamed: 14':'возраст от 35 до 39',
    'Unnamed: 15':'возраст от 40 до 44',
    'Unnamed: 16':'возраст от 45 до 49',
    'Unnamed: 17':'возраст от 50 до 54',
    'Unnamed: 18':'возраст от 55 до 59',
    'Unnamed: 19':'возраст от 60 до 64',
    'Unnamed: 20':'возраст от 65 до 69',
    'Unnamed: 21':'возраст от 70 до 74',
    'Unnamed: 22':'возраст от 75 до 79',
    'Unnamed: 23':'возраст от 80 до 84',
    'Unnamed: 24':'возраст от 85'})
table9.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 0                                      NaN        NaN                     NaN
# 1  Злокачественные новообразования - всего     С00-96                  224.87
# 2                                     Губа        С00                    0.65
# 3                                     Язык     С01.02                    1.38
# 4                   Большие слюнные железы     С07.08                    0.49
#
#    ошибочно-стандартный показатель                    показатель  \
# 0                              NaN                           NaN
# 1                             0.32  Абс.число\n"Грубый" Уд.вес.%
# 2                             0.02  Абс.число\n"Грубый" Уд.вес.%
# 3                             0.02  Абс.число\n"Грубый" Уд.вес.%
# 4                             0.02  Абс.число\n"Грубый" Уд.вес.%
#
#                     всего    возраст от 0 до 4  возраст от 5 до 9  \
# ...

# %%
#можем удалить строку
table9.drop(labels = [0], axis= 0, inplace= True)
table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#                      показатель                   всего    возраст от 0 до 4  \
# 1  Абс.число\n"Грубый" Уд.вес.%  580415\n397.91\n100.00  1343\n17.13\n100.00
# 2  Абс.число\n"Грубый" Уд.вес.%        1902\n1.30\n0.33        1\n0.01\n0.07
# ...

# %%
#можем удалить столбец
table9.drop('показатель', axis= 1 , inplace= True)
table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#                     всего    возраст от 0 до 4  возраст от 5 до 9  \
# 1  580415\n397.91\n100.00  1343\n17.13\n100.00  871\n9.08\n100.00
# 2        1902\n1.30\n0.33        1\n0.01\n0.07      0\n0.00\n0.00
# 3        3335\n2.29\n0.57        0\n0.00\n0.00      0\n0.00\n0.00
# ...

# %%
new_table9 = table9['всего'].str.split('\n',expand=True)
new_table9.columns=['всего абс','всего грубый','всего уд.']
final_table9 = pd.concat([table9,new_table9],axis=1)
final_table9 = final_table9.drop('всего',axis=1)
final_table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#      возраст от 0 до 4  возраст от 5 до 9 возраст от 10 до 14  \
# 1  1343\n17.13\n100.00  871\n9.08\n100.00   784\n9.30\n100.00
# 2        1\n0.01\n0.07      0\n0.00\n0.00       0\n0.00\n0.00
# 3        0\n0.00\n0.00      0\n0.00\n0.00       1\n0.01\n0.13
# ...

# %%
new_table9 = final_table9['возраст от 0 до 4'].str.split('\n',expand=True)
new_table9.columns=['возраст от 0 до 4 абс','возраст от 0 до 4 грубый','возраст от 0 до 4 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 0 до 4',axis=1)
final_table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  возраст от 5 до 9  \
# 1                  224.87                             0.32  871\n9.08\n100.00
# 2                    0.65                             0.02      0\n0.00\n0.00
# 3                    1.38                             0.02      0\n0.00\n0.00
# 4                    0.49                             0.02      2\n0.02\n0.23
# 5                    2.08                             0.03      0\n0.00\n0.00
#
#   возраст от 10 до 14  возраст от 15 до 19  возраст от 20 до 24  \
# 1   784\n9.30\n100.00  1223\n16.63\n100.00  1514\n22.35\n100.00
# ...

# %%
new_table9 = final_table9['возраст от 5 до 9'].str.split('\n',expand=True)
new_table9.columns=['возраст от 5 до 9 абс','возраст от 5 до 9 грубый','возраст от 5 до 9 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 5 до 9',axis=1)
final_table9
# Out:
#                                           локализация  \
# 1             Злокачественные новообразования - всего
# 2                                                Губа
# 3                                                Язык
# 4                              Большие слюнные железы
# 5             Другие и неуточненные части полости рта
# 6                                          Ротоглотка
# 7                                          Носоглотка
# 8                                       Гортаноглотка
# 9                                             Пищевод
# 10                                            Желудок
# 11                                    Тонкий кишечник
# 12                                    Ободочная кишка
# 13           Прямая кишка. ректосиг. соединение. анус
# 14                Печень и внутрипеч. желчные протоки
# 15     Желчный пузырь и внепеченочные желчные протоки
# 16                               Поджелудочная железа
# ...

# %%
new_table9 = final_table9['возраст от 10 до 14'].str.split('\n',expand=True)
new_table9.columns=['возраст от 10 до 14 абс','возраст от 10 до 14 грубый','возраст от 10 до 14 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 10 до 14',axis=1)
final_table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#    возраст от 15 до 19  возраст от 20 до 24  возраст от 25 до 29  \
# 1  1223\n16.63\n100.00  1514\n22.35\n100.00  2962\n35.76\n100.00
# 2        0\n0.00\n0.00        1\n0.01\n0.07        3\n0.04\n0.10
# 3        1\n0.01\n0.08        4\n0.06\n0.26        7\n0.08\n0.24
# ...

# %%
new_table9 = final_table9['возраст от 15 до 19'].str.split('\n',expand=True)
new_table9.columns=['возраст от 15 до 19 абс','возраст от 15 до 19 грубый','возраст от 15 до 19 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 15 до 19',axis=1)
final_table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#    возраст от 20 до 24  возраст от 25 до 29  возраст от 30 до 34  \
# 1  1514\n22.35\n100.00  2962\n35.76\n100.00  7863\n64.60\n100.00
# 2        1\n0.01\n0.07        3\n0.04\n0.10        4\n0.03\n0.05
# 3        4\n0.06\n0.26        7\n0.08\n0.24       31\n0.25\n0.39
# ...

# %%
new_table9 = final_table9['возраст от 20 до 24'].str.split('\n',expand=True)
new_table9.columns=['возраст от 20 до 24 абс','возраст от 20 до 24 грубый','возраст от 20 до 24 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 20 до 24',axis=1)
final_table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#    возраст от 25 до 29  возраст от 30 до 34    возраст от 35 до 39  \
# 1  2962\n35.76\n100.00  7863\n64.60\n100.00  13776\n112.00\n100.00
# 2        3\n0.04\n0.10        4\n0.03\n0.05         18\n0.15\n0.13
# 3        7\n0.08\n0.24       31\n0.25\n0.39         64\n0.52\n0.46
# ...

# %%
new_table9 = final_table9['возраст от 25 до 29'].str.split('\n',expand=True)
new_table9.columns=['возраст от 25 до 29 абс','возраст от 25 до 29 грубый','возраст от 25 до 29 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 25 до 29',axis=1)
final_table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#    возраст от 30 до 34    возраст от 35 до 39    возраст от 40 до 44  \
# 1  7863\n64.60\n100.00  13776\n112.00\n100.00  20153\n183.74\n100.00
# 2        4\n0.03\n0.05         18\n0.15\n0.13         26\n0.24\n0.13
# ...

# %%
new_table9 = final_table9['возраст от 30 до 34'].str.split('\n',expand=True)
new_table9.columns=['возраст от 30 до 34 абс','возраст от 30 до 34 грубый','возраст от 30 до 34 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 30 до 34',axis=1)
final_table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#      возраст от 35 до 39    возраст от 40 до 44    возраст от 45 до 49  \
# 1  13776\n112.00\n100.00  20153\n183.74\n100.00  28794\n286.24\n100.00
# 2         18\n0.15\n0.13         26\n0.24\n0.13         51\n0.51\n0.18
# ...

# %%
new_table9 = final_table9['возраст от 35 до 39'].str.split('\n',expand=True)
new_table9.columns=['возраст от 35 до 39 абс','возраст от 35 до 39 грубый','возраст от 35 до 39 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 35 до 39',axis=1)
final_table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#      возраст от 40 до 44    возраст от 45 до 49    возраст от 50 до 54  \
# 1  20153\n183.74\n100.00  28794\n286.24\n100.00  37250\n416.94\n100.00
# 2         26\n0.24\n0.13         51\n0.51\n0.18         78\n0.87\n0.21
# ...

# %%
new_table9 = final_table9['возраст от 40 до 44'].str.split('\n',expand=True)
new_table9.columns=['возраст от 40 до 44 абс','возраст от 40 до 44 грубый','возраст от 40 до 44 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 40 до 44',axis=1)
final_table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#      возраст от 45 до 49    возраст от 50 до 54    возраст от 55 до 59  \
# 1  28794\n286.24\n100.00  37250\n416.94\n100.00  60654\n631.62\n100.00
# 2         51\n0.51\n0.18         78\n0.87\n0.21        155\n1.61\n0.26
# ...

# %%
new_table9 = final_table9['возраст от 45 до 49'].str.split('\n',expand=True)
new_table9.columns=['возраст от 45 до 49 абс','возраст от 45 до 49 грубый','возраст от 45 до 49 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 45 до 49',axis=1)
final_table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#      возраст от 50 до 54    возраст от 55 до 59    возраст от 60 до 64  \
# 1  37250\n416.94\n100.00  60654\n631.62\n100.00  94433\n915.91\n100.00
# 2         78\n0.87\n0.21        155\n1.61\n0.26        324\n3.14\n0.34
# ...

# %%
new_table9 = final_table9['возраст от 50 до 54'].str.split('\n',expand=True)
new_table9.columns=['возраст от 50 до 54 абс','возраст от 50 до 54 грубый','возраст от 50 до 54 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 50 до 54',axis=1)
final_table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#      возраст от 55 до 59    возраст от 60 до 64      возраст от 65 до 69  \
# 1  60654\n631.62\n100.00  94433\n915.91\n100.00  105013\n1233.53\n100.00
# 2        155\n1.61\n0.26        324\n3.14\n0.34          369\n4.33\n0.35
# ...

# %%
new_table9 = final_table9['возраст от 55 до 59'].str.split('\n',expand=True)
new_table9.columns=['возраст от 55 до 59 абс','возраст от 55 до 59 грубый','возраст от 55 до 59 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 55 до 59',axis=1)
final_table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#      возраст от 60 до 64      возраст от 65 до 69     возраст от 70 до 74  \
# 1  94433\n915.91\n100.00  105013\n1233.53\n100.00  94377\n1488.35\n100.00
# 2        324\n3.14\n0.34          369\n4.33\n0.35         308\n4.86\n0.33
# ...

# %%
new_table9 = final_table9['возраст от 60 до 64'].str.split('\n',expand=True)
new_table9.columns=['возраст от 60 до 64 абс','возраст от 60 до 64 грубый','возраст от 60 до 64 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 60 до 64',axis=1)
final_table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#        возраст от 65 до 69     возраст от 70 до 74     возраст от 75 до 79  \
# 1  105013\n1233.53\n100.00  94377\n1488.35\n100.00  40010\n1484.35\n100.00
# 2          369\n4.33\n0.35         308\n4.86\n0.33         164\n6.08\n0.41
# ...

# %%
new_table9 = final_table9['возраст от 65 до 69'].str.split('\n',expand=True)
new_table9.columns=['возраст от 65 до 69 абс','возраст от 65 до 69 грубый','возраст от 65 до 69 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 65 до 69',axis=1)
final_table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#       возраст от 70 до 74     возраст от 75 до 79     возраст от 80 до 84  \
# 1  94377\n1488.35\n100.00  40010\n1484.35\n100.00  47552\n1342.78\n100.00
# 2         308\n4.86\n0.33         164\n6.08\n0.41         239\n6.75\n0.50
# ...

# %%
new_table9 = final_table9['возраст от 70 до 74'].str.split('\n',expand=True)
new_table9.columns=['возраст от 70 до 74 абс','возраст от 70 до 74 грубый','возраст от 70 до 74 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 70 до 74',axis=1)
final_table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#       возраст от 75 до 79     возраст от 80 до 84           возраст от 85  \
# 1  40010\n1484.35\n100.00  47552\n1342.78\n100.00  21843\n1010.66\n100.00
# 2         164\n6.08\n0.41         239\n6.75\n0.50         161\n7.45\n0.74
# ...

# %%
new_table9 = final_table9['возраст от 75 до 79'].str.split('\n',expand=True)
new_table9.columns=['возраст от 75 до 79 абс','возраст от 75 до 79 грубый','возраст от 75 до 79 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 75 до 79',axis=1)
final_table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#       возраст от 80 до 84           возраст от 85 всего абс всего грубый  \
# 1  47552\n1342.78\n100.00  21843\n1010.66\n100.00    580415       397.91
# 2         239\n6.75\n0.50         161\n7.45\n0.74      1902         1.30
# ...

# %%
new_table9 = final_table9['возраст от 80 до 84'].str.split('\n',expand=True)
new_table9.columns=['возраст от 80 до 84 абс','возраст от 80 до 84 грубый','возраст от 80 до 84 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 80 до 84',axis=1)
final_table9.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель  ошибочно-стандартный показатель  \
# 1                  224.87                             0.32
# 2                    0.65                             0.02
# 3                    1.38                             0.02
# 4                    0.49                             0.02
# 5                    2.08                             0.03
#
#             возраст от 85 всего абс всего грубый всего уд.  \
# 1  21843\n1010.66\n100.00    580415       397.91    100.00
# 2         161\n7.45\n0.74      1902         1.30      0.33
# 3          62\n2.87\n0.28      3335         2.29      0.57
# ...

# %%
new_table9 = final_table9['возраст от 85'].str.split('\n',expand=True)
new_table9.columns=['возраст от 85 абс','возраст от 85 грубый','возраст от 85 уд.']
final_table9 = pd.concat([final_table9,new_table9],axis=1)
final_table9 = final_table9.drop('возраст от 85',axis=1)
final_table9
# Out:
#                                           локализация  \
# 1             Злокачественные новообразования - всего
# 2                                                Губа
# 3                                                Язык
# 4                              Большие слюнные железы
# 5             Другие и неуточненные части полости рта
# 6                                          Ротоглотка
# 7                                          Носоглотка
# 8                                       Гортаноглотка
# 9                                             Пищевод
# 10                                            Желудок
# 11                                    Тонкий кишечник
# 12                                    Ободочная кишка
# 13           Прямая кишка. ректосиг. соединение. анус
# 14                Печень и внутрипеч. желчные протоки
# 15     Желчный пузырь и внепеченочные желчные протоки
# 16                               Поджелудочная железа
# ...

# %%
final_table9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 1 to 39
# Data columns (total 61 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   локализация                      39 non-null     object
#  1   код мкб 10                       39 non-null     object
#  2   стандартный показатель           39 non-null     float64
#  3   ошибочно-стандартный показатель  39 non-null     float64
#  4   всего абс                        39 non-null     object
#  5   всего грубый                     39 non-null     object
#  6   всего уд.                        39 non-null     object
#  7   возраст от 0 до 4 абс            39 non-null     object
#  8   возраст от 0 до 4 грубый         39 non-null     object
#  9   возраст от 0 до 4 уд.            39 non-null     object
#  10  возраст от 5 до 9 абс            39 non-null     object
#  11  возраст от 5 до 9 грубый         39 non-null     object
# ...

# %%
#преобразуем тип данных
final_table9.loc[:, 'всего абс': 'возраст от 85 уд.']=final_table9.loc[:, 'всего абс': 'возраст от 85 уд.'].astype('float')
morbidity_all=final_table9

# %%
morbidity_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 1 to 39
# Data columns (total 61 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   локализация                      39 non-null     object
#  1   код мкб 10                       39 non-null     object
#  2   стандартный показатель           39 non-null     float64
#  3   ошибочно-стандартный показатель  39 non-null     float64
#  4   всего абс                        39 non-null     float64
#  5   всего грубый                     39 non-null     float64
#  6   всего уд.                        39 non-null     float64
#  7   возраст от 0 до 4 абс            39 non-null     float64
#  8   возраст от 0 до 4 грубый         39 non-null     float64
#  9   возраст от 0 до 4 уд.            39 non-null     float64
#  10  возраст от 5 до 9 абс            39 non-null     float64
#  11  возраст от 5 до 9 грубый         39 non-null     float64
# ...

# %% [markdown]
# ## Таблица 10

# %%
mantable10 = pd.read_excel('/datasets/2021_Таблица_010.xlsx', header = [3], decimal=',')
mantable10 = mantable10.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)

# %%
mantable10.dtypes
# Out:
# Локализация, нозологическая форма     object
# Unnamed: 1                           float64
# Код МКБ 10                            object
# Станд. пока- затель                  float64
# Ошиб. станд. показ.                  float64
# Показа- тель                          object
# Возраст                               object
# Unnamed: 7                            object
# Unnamed: 8                            object
# Unnamed: 9                            object
# Unnamed: 10                           object
# Unnamed: 11                           object
# Unnamed: 12                           object
# Unnamed: 13                           object
# Unnamed: 14                           object
# Unnamed: 15                           object
# Unnamed: 16                           object
# Unnamed: 17                           object
# Unnamed: 18                           object
# Unnamed: 19                           object
# Unnamed: 20                           object
# ...

# %%
#можем удалить столбец
mantable10.drop('Unnamed: 1', axis= 1 , inplace= True)
mantable10.head()
# Out:
#          Локализация, нозологическая форма Код МКБ 10  Станд. пока- затель  \
# 0                                      NaN        NaN                  NaN
# 1  Злокачественные новообразования - всего     С00-96               255.54
# 2                                     Губа        С00                 1.33
# 3                                     Язык     С01.02                 2.24
# 4                   Большие слюнные железы     С07.08                 0.57
#
#    Ошиб. станд. показ.                  Показа- тель                 Возраст  \
# 0                  NaN                           NaN                   Всего
# 1                 0.51  Абс.число\n"Грубый" Уд.вес.%  265039\n391.20\n100.00
# 2                 0.04  Абс.число\n"Грубый" Уд.вес.%        1422\n2.10\n0.54
# 3                 0.05  Абс.число\n"Грубый" Уд.вес.%        2248\n3.32\n0.85
# 4                 0.02  Абс.число\n"Грубый" Уд.вес.%         585\n0.86\n0.22
#
# ...

# %%
mantable10.drop(labels = [0], axis= 0, inplace= True)
mantable10.head()
# Out:
#          Локализация, нозологическая форма  Код МКБ 10  Станд. пока- затель  \
# 1  Злокачественные новообразования - всего      С00-96               255.54
# 2                                     Губа         С00                 1.33
# 3                                     Язык      С01.02                 2.24
# 4                   Большие слюнные железы      С07.08                 0.57
# 5  Другие и неуточненные части полости рта  C03-06. 09                 3.44
#
#    Ошиб. станд. показ.                  Показа- тель                 Возраст  \
# 1                 0.51  Абс.число\n"Грубый" Уд.вес.%  265039\n391.20\n100.00
# 2                 0.04  Абс.число\n"Грубый" Уд.вес.%        1422\n2.10\n0.54
# 3                 0.05  Абс.число\n"Грубый" Уд.вес.%        2248\n3.32\n0.85
# 4                 0.02  Абс.число\n"Грубый" Уд.вес.%         585\n0.86\n0.22
# 5                 0.06  Абс.число\n"Грубый" Уд.вес.%        3450\n5.09\n1.30
#
# ...

# %%
#переименуем столбцы
mantable10 = mantable10.rename(
    columns = {
    'Локализация, нозологическая форма':'локализация',
    'Код МКБ 10':'код мкб 10',
    'Станд. пока- затель':'стандартный показатель муж',
    'Ошиб. станд. показ.':'ошибочно-стандартный показатель муж',
    'Показа- тель':'показатель муж',
    'Возраст':'всего муж',
    'Unnamed: 7':'возраст от 0 до 4 муж',
    'Unnamed: 8':'возраст от 5 до 9 муж',
    'Unnamed: 9':'возраст от 10 до 14 муж',
    'Unnamed: 10':'возраст от 15 до 19 муж',
    'Unnamed: 11':'возраст от 20 до 24 муж',
    'Unnamed: 12':'возраст от 25 до 29 муж',
    'Unnamed: 13':'возраст от 30 до 34 муж',
    'Unnamed: 14':'возраст от 35 до 39 муж',
    'Unnamed: 15':'возраст от 40 до 44 муж',
    'Unnamed: 16':'возраст от 45 до 49 муж',
    'Unnamed: 17':'возраст от 50 до 54 муж',
    'Unnamed: 18':'возраст от 55 до 59 муж',
    'Unnamed: 19':'возраст от 60 до 64 муж',
    'Unnamed: 20':'возраст от 65 до 69 муж',
    'Unnamed: 21':'возраст от 70 до 74 муж',
    'Unnamed: 22':'возраст от 75 до 79 муж',
    'Unnamed: 23':'возраст от 80 до 84 муж',
    'Unnamed: 24':'возраст от 85 муж'})
mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#                  показатель муж               всего муж возраст от 0 до 4 муж  \
# 1  Абс.число\n"Грубый" Уд.вес.%  265039\n391.20\n100.00    722\n17.91\n100.00
# ...

# %%
#можем удалить столбец
mantable10.drop('показатель муж', axis= 1 , inplace= True)
mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#                 всего муж возраст от 0 до 4 муж возраст от 5 до 9 муж  \
# 1  265039\n391.20\n100.00    722\n17.91\n100.00    497\n10.09\n100.00
# 2        1422\n2.10\n0.54         1\n0.02\n0.14         0\n0.00\n0.00
# ...

# %%
new_mantable10 = mantable10['всего муж'].str.split('\n',expand=True)
new_mantable10.columns=['всего муж абс','всего муж грубый','всего муж уд.']
final_mantable10 = pd.concat([mantable10,new_mantable10],axis=1)
final_mantable10 = final_mantable10.drop('всего муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   возраст от 0 до 4 муж возраст от 5 до 9 муж возраст от 10 до 14 муж  \
# 1    722\n17.91\n100.00    497\n10.09\n100.00       408\n9.44\n100.00
# 2         1\n0.02\n0.14         0\n0.00\n0.00           0\n0.00\n0.00
# ...

# %%
final_mantable10[['возраст от 0 до 4 муж абс', 'возраст от 0 до 4 муж грубый','возраст от 0 до 4 муж уд.']] = final_mantable10['возраст от 0 до 4 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 0 до 4 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   возраст от 5 до 9 муж возраст от 10 до 14 муж возраст от 15 до 19 муж  \
# 1    497\n10.09\n100.00       408\n9.44\n100.00      597\n15.90\n100.00
# 2         0\n0.00\n0.00           0\n0.00\n0.00           0\n0.00\n0.00
# ...

# %%
final_mantable10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 1 to 42
# Data columns (total 27 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   локализация                          42 non-null     object
#  1   код мкб 10                           42 non-null     object
#  2   стандартный показатель муж           42 non-null     float64
#  3   ошибочно-стандартный показатель муж  42 non-null     float64
#  4   возраст от 5 до 9 муж                42 non-null     object
#  5   возраст от 10 до 14 муж              42 non-null     object
#  6   возраст от 15 до 19 муж              42 non-null     object
#  7   возраст от 20 до 24 муж              42 non-null     object
#  8   возраст от 25 до 29 муж              42 non-null     object
#  9   возраст от 30 до 34 муж              42 non-null     object
#  10  возраст от 35 до 39 муж              42 non-null     object
# ...

# %%
final_mantable10[['возраст от 5 до 9 муж абс', 'возраст от 5 до 9 муж грубый','возраст от 5 до 9 муж уд.']] = final_mantable10['возраст от 5 до 9 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 5 до 9 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   возраст от 10 до 14 муж возраст от 15 до 19 муж возраст от 20 до 24 муж  \
# 1       408\n9.44\n100.00      597\n15.90\n100.00      656\n19.03\n100.00
# 2           0\n0.00\n0.00           0\n0.00\n0.00           1\n0.03\n0.15
# ...

# %%
final_mantable10[['возраст от 10 до 14 муж абс', 'возраст от 10 до 14 муж грубый','возраст от 10 до 14 муж уд.']] = final_mantable10['возраст от 10 до 14 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 10 до 14 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   возраст от 15 до 19 муж возраст от 20 до 24 муж возраст от 25 до 29 муж  \
# 1      597\n15.90\n100.00      656\n19.03\n100.00     1003\n23.60\n100.00
# 2           0\n0.00\n0.00           1\n0.03\n0.15           2\n0.05\n0.20
# ...

# %%
final_mantable10[['возраст от 15 до 19 муж абс', 'возраст от 15 до 19 муж грубый','возраст от 15 до 19 муж уд.']] = final_mantable10['возраст от 15 до 19 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 15 до 19 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   возраст от 20 до 24 муж возраст от 25 до 29 муж возраст от 30 до 34 муж  \
# 1      656\n19.03\n100.00     1003\n23.60\n100.00     2265\n36.79\n100.00
# 2           1\n0.03\n0.15           2\n0.05\n0.20           4\n0.06\n0.18
# ...

# %%
final_mantable10[['возраст от 20 до 24 муж абс', 'возраст от 20 до 24 муж грубый','возраст от 20 до 24 муж уд.']] = final_mantable10['возраст от 20 до 24 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 20 до 24 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   возраст от 25 до 29 муж возраст от 30 до 34 муж возраст от 35 до 39 муж  \
# 1     1003\n23.60\n100.00     2265\n36.79\n100.00     3876\n63.45\n100.00
# 2           2\n0.05\n0.20           4\n0.06\n0.18          16\n0.26\n0.41
# ...

# %%
final_mantable10[['возраст от 25 до 29 муж абс', 'возраст от 25 до 29 муж грубый','возраст от 25 до 29 муж уд.']] = final_mantable10['возраст от 25 до 29 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 25 до 29 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   возраст от 30 до 34 муж возраст от 35 до 39 муж возраст от 40 до 44 муж  \
# 1     2265\n36.79\n100.00     3876\n63.45\n100.00    6095\n114.33\n100.00
# 2           4\n0.06\n0.18          16\n0.26\n0.41          24\n0.45\n0.39
# ...

# %%
final_mantable10[['возраст от 30 до 34 муж абс', 'возраст от 30 до 34 муж грубый','возраст от 30 до 34 муж уд.']] = final_mantable10['возраст от 30 до 34 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 30 до 34 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   возраст от 35 до 39 муж возраст от 40 до 44 муж возраст от 45 до 49 муж  \
# 1     3876\n63.45\n100.00    6095\n114.33\n100.00   10083\n210.63\n100.00
# 2          16\n0.26\n0.41          24\n0.45\n0.39          50\n1.04\n0.50
# ...

# %%
final_mantable10[['возраст от 35 до 39 муж абс', 'возраст от 35 до 39 муж грубый','возраст от 35 до 39 муж уд.']] = final_mantable10['возраст от 35 до 39 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 35 до 39 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   возраст от 40 до 44 муж возраст от 45 до 49 муж возраст от 50 до 54 муж  \
# 1    6095\n114.33\n100.00   10083\n210.63\n100.00   15629\n373.12\n100.00
# 2          24\n0.45\n0.39          50\n1.04\n0.50          72\n1.72\n0.46
# ...

# %%
final_mantable10[['возраст от 40 до 44 муж абс', 'возраст от 40 до 44 муж грубый','возраст от 40 до 44 муж уд.']] = final_mantable10['возраст от 40 до 44 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 40 до 44 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   возраст от 45 до 49 муж возраст от 50 до 54 муж возраст от 55 до 59 муж  \
# 1   10083\n210.63\n100.00   15629\n373.12\n100.00   29107\n676.33\n100.00
# 2          50\n1.04\n0.50          72\n1.72\n0.46         138\n3.21\n0.47
# ...

# %%
final_mantable10[['возраст от 45 до 49 муж абс', 'возраст от 45 до 49 муж грубый','возраст от 45 до 49 муж уд.']] = final_mantable10['возраст от 45 до 49 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 45 до 49 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   возраст от 50 до 54 муж возраст от 55 до 59 муж возраст от 60 до 64 муж  \
# 1   15629\n373.12\n100.00   29107\n676.33\n100.00  48403\n1109.65\n100.00
# 2          72\n1.72\n0.46         138\n3.21\n0.47         291\n6.67\n0.60
# ...

# %%
final_mantable10[['возраст от 50 до 54 муж абс', 'возраст от 50 до 54 муж грубый','возраст от 50 до 54 муж уд.']] = final_mantable10['возраст от 50 до 54 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 50 до 54 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   возраст от 55 до 59 муж возраст от 60 до 64 муж возраст от 65 до 69 муж  \
# 1   29107\n676.33\n100.00  48403\n1109.65\n100.00  54724\n1671.65\n100.00
# 2         138\n3.21\n0.47         291\n6.67\n0.60         301\n9.19\n0.55
# ...

# %%
final_mantable10[['возраст от 55 до 59 муж абс', 'возраст от 55 до 59 муж грубый','возраст от 55 до 59 муж уд.']] = final_mantable10['возраст от 55 до 59 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 55 до 59 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   возраст от 60 до 64 муж возраст от 65 до 69 муж возраст от 70 до 74 муж  \
# 1  48403\n1109.65\n100.00  54724\n1671.65\n100.00  47439\n2122.85\n100.00
# 2         291\n6.67\n0.60         301\n9.19\n0.55        246\n11.01\n0.52
# ...

# %%
final_mantable10[['возраст от 60 до 64 муж абс', 'возраст от 60 до 64 муж грубый','возраст от 60 до 64 муж уд.']] = final_mantable10['возраст от 60 до 64 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 60 до 64 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   возраст от 65 до 69 муж возраст от 70 до 74 муж возраст от 75 до 79 муж  \
# 1  54724\n1671.65\n100.00  47439\n2122.85\n100.00  18071\n2172.25\n100.00
# 2         301\n9.19\n0.55        246\n11.01\n0.52         96\n11.54\n0.53
# ...

# %%
final_mantable10[['возраст от 65 до 69 муж абс', 'возраст от 65 до 69 муж грубый','возраст от 65 до 69 муж уд.']] = final_mantable10['возраст от 65 до 69 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 65 до 69 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   возраст от 70 до 74 муж возраст от 75 до 79 муж возраст от 80 до 84 муж  \
# 1  47439\n2122.85\n100.00  18071\n2172.25\n100.00  18440\n2001.18\n100.00
# 2        246\n11.01\n0.52         96\n11.54\n0.53        126\n13.67\n0.68
# ...

# %%
final_mantable10[['возраст от 70 до 74 муж абс', 'возраст от 70 до 74 муж грубый','возраст от 70 до 74 муж уд.']] = final_mantable10['возраст от 70 до 74 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 70 до 74 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   возраст от 75 до 79 муж возраст от 80 до 84 муж      возраст от 85 муж  \
# 1  18071\n2172.25\n100.00  18440\n2001.18\n100.00  7024\n1350.43\n100.00
# 2         96\n11.54\n0.53        126\n13.67\n0.68        54\n10.38\n0.77
# ...

# %%
final_mantable10[['возраст от 75 до 79 муж абс', 'возраст от 75 до 79 муж грубый','возраст от 75 до 79 муж уд.']] = final_mantable10['возраст от 75 до 79 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 75 до 79 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   возраст от 80 до 84 муж      возраст от 85 муж всего муж абс  \
# 1  18440\n2001.18\n100.00  7024\n1350.43\n100.00        265039
# 2        126\n13.67\n0.68        54\n10.38\n0.77          1422
# ...

# %%
final_mantable10[['возраст от 80 до 84 муж абс', 'возраст от 80 до 84 муж грубый','возраст от 80 до 84 муж уд.']] = final_mantable10['возраст от 80 до 84 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 80 до 84 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#        возраст от 85 муж всего муж абс всего муж грубый всего муж уд.  \
# 1  7024\n1350.43\n100.00        265039           391.20        100.00
# 2        54\n10.38\n0.77          1422             2.10          0.54
# ...

# %%
final_mantable10[['возраст от 85 муж абс', 'возраст от 85 муж грубый','возраст от 85 муж уд.']] = final_mantable10['возраст от 85 муж'].str.split('\n',expand=True)
final_mantable10 = final_mantable10.drop('возраст от 85 муж',axis=1)
final_mantable10.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      255.54                                 0.51
# 2                        1.33                                 0.04
# 3                        2.24                                 0.05
# 4                        0.57                                 0.02
# 5                        3.44                                 0.06
#
#   всего муж абс всего муж грубый всего муж уд. возраст от 0 до 4 муж абс  \
# 1        265039           391.20        100.00                       722
# 2          1422             2.10          0.54                         1
# ...

# %%
#преобразуем тип данных
final_mantable10.loc[:, 'всего муж абс': 'возраст от 85 муж уд.']=final_mantable10.loc[:, 'всего муж абс': 'возраст от 85 муж уд.'].astype('float')
morbidity_man=final_mantable10

# %%
morbidity_man.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 1 to 42
# Data columns (total 61 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   локализация                          42 non-null     object
#  1   код мкб 10                           42 non-null     object
#  2   стандартный показатель муж           42 non-null     float64
#  3   ошибочно-стандартный показатель муж  42 non-null     float64
#  4   всего муж абс                        42 non-null     float64
#  5   всего муж грубый                     42 non-null     float64
#  6   всего муж уд.                        42 non-null     float64
#  7   возраст от 0 до 4 муж абс            42 non-null     float64
#  8   возраст от 0 до 4 муж грубый         42 non-null     float64
#  9   возраст от 0 до 4 муж уд.            42 non-null     float64
#  10  возраст от 5 до 9 муж абс            42 non-null     float64
# ...

# %% [markdown]
# ## Таблица 11

# %%
womantable11 = pd.read_excel('/datasets/2021_Таблица_011.xlsx', header = [3], decimal=',')
womantable11 = womantable11.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)

# %%
womantable11.head()
# Out:
#          Локализация, нозологическая форма  Unnamed: 1 Код МКБ 10  \
# 0                                      NaN         NaN        NaN
# 1  Злокачественные новообразования - всего         NaN     С00-96
# 2                                     Губа         NaN        С00
# 3                                     Язык         NaN     С01.02
# 4                   Большие слюнные железы         NaN     С07.08
#
#    Станд. пока- затель  Ошиб. станд. показ.                  Показа- тель  \
# 0                  NaN                  NaN                           NaN
# 1               213.58                 0.42  Абс.число\n"Грубый" Уд.вес.%
# 2                 0.21                 0.01  Абс.число\n"Грубый" Уд.вес.%
# 3                 0.75                 0.02  Абс.число\n"Грубый" Уд.вес.%
# 4                 0.45                 0.02  Абс.число\n"Грубый" Уд.вес.%
#
#                   Возраст          Unnamed: 7         Unnamed: 8  \
# ...

# %%
womantable11.dtypes
# Out:
# Локализация, нозологическая форма     object
# Unnamed: 1                           float64
# Код МКБ 10                            object
# Станд. пока- затель                  float64
# Ошиб. станд. показ.                  float64
# Показа- тель                          object
# Возраст                               object
# Unnamed: 7                            object
# Unnamed: 8                            object
# Unnamed: 9                            object
# Unnamed: 10                           object
# Unnamed: 11                           object
# Unnamed: 12                           object
# Unnamed: 13                           object
# Unnamed: 14                           object
# Unnamed: 15                           object
# Unnamed: 16                           object
# Unnamed: 17                           object
# Unnamed: 18                           object
# Unnamed: 19                           object
# Unnamed: 20                           object
# ...

# %%
#можем удалить столбец
womantable11.drop('Unnamed: 1', axis= 1 , inplace= True)
womantable11.head()
# Out:
#          Локализация, нозологическая форма Код МКБ 10  Станд. пока- затель  \
# 0                                      NaN        NaN                  NaN
# 1  Злокачественные новообразования - всего     С00-96               213.58
# 2                                     Губа        С00                 0.21
# 3                                     Язык     С01.02                 0.75
# 4                   Большие слюнные железы     С07.08                 0.45
#
#    Ошиб. станд. показ.                  Показа- тель                 Возраст  \
# 0                  NaN                           NaN                   Всего
# 1                 0.42  Абс.число\n"Грубый" Уд.вес.%  315376\n403.74\n100.00
# 2                 0.01  Абс.число\n"Грубый" Уд.вес.%         480\n0.61\n0.15
# 3                 0.02  Абс.число\n"Грубый" Уд.вес.%        1087\n1.39\n0.34
# 4                 0.02  Абс.число\n"Грубый" Уд.вес.%         628\n0.80\n0.20
#
# ...

# %%
#можем удалить столбец
womantable11.drop('Показа- тель', axis= 1 , inplace= True)
womantable11.head()
# Out:
#          Локализация, нозологическая форма Код МКБ 10  Станд. пока- затель  \
# 0                                      NaN        NaN                  NaN
# 1  Злокачественные новообразования - всего     С00-96               213.58
# 2                                     Губа        С00                 0.21
# 3                                     Язык     С01.02                 0.75
# 4                   Большие слюнные железы     С07.08                 0.45
#
#    Ошиб. станд. показ.                 Возраст          Unnamed: 7  \
# 0                  NaN                   Всего                 0-4
# 1                 0.42  315376\n403.74\n100.00  621\n16.31\n100.00
# 2                 0.01         480\n0.61\n0.15       0\n0.00\n0.00
# 3                 0.02        1087\n1.39\n0.34       0\n0.00\n0.00
# 4                 0.02         628\n0.80\n0.20       1\n0.03\n0.16
#
#           Unnamed: 8         Unnamed: 9         Unnamed: 10  \
# ...

# %%
#и удалим не нужную строку
womantable11.drop(labels = [0], axis= 0, inplace= True)
womantable11.head()
# Out:
#          Локализация, нозологическая форма  Код МКБ 10  Станд. пока- затель  \
# 1  Злокачественные новообразования - всего      С00-96               213.58
# 2                                     Губа         С00                 0.21
# 3                                     Язык      С01.02                 0.75
# 4                   Большие слюнные железы      С07.08                 0.45
# 5  Другие и неуточненные части полости рта  C03-06. 09                 1.07
#
#    Ошиб. станд. показ.                 Возраст          Unnamed: 7  \
# 1                 0.42  315376\n403.74\n100.00  621\n16.31\n100.00
# 2                 0.01         480\n0.61\n0.15       0\n0.00\n0.00
# 3                 0.02        1087\n1.39\n0.34       0\n0.00\n0.00
# 4                 0.02         628\n0.80\n0.20       1\n0.03\n0.16
# 5                 0.03        1505\n1.93\n0.48       0\n0.00\n0.00
#
#           Unnamed: 8         Unnamed: 9         Unnamed: 10  \
# ...

# %%
#переименуем столбцы
womantable11 = womantable11.rename(
    columns = {
    'Локализация, нозологическая форма':'локализация',
    'Код МКБ 10':'код мкб 10',
    'Станд. пока- затель':'стандартный показатель жен',
    'Ошиб. станд. показ.':'ошибочно-стандартный показатель жен',
    'Возраст':'всего жен',
    'Unnamed: 7':'возраст от 0 до 4 жен',
    'Unnamed: 8':'возраст от 5 до 9 жен',
    'Unnamed: 9':'возраст от 10 до 14 жен',
    'Unnamed: 10':'возраст от 15 до 19 жен',
    'Unnamed: 11':'возраст от 20 до 24 жен',
    'Unnamed: 12':'возраст от 25 до 29 жен',
    'Unnamed: 13':'возраст от 30 до 34 жен',
    'Unnamed: 14':'возраст от 35 до 39 жен',
    'Unnamed: 15':'возраст от 40 до 44 жен',
    'Unnamed: 16':'возраст от 45 до 49 жен',
    'Unnamed: 17':'возраст от 50 до 54 жен',
    'Unnamed: 18':'возраст от 55 до 59 жен',
    'Unnamed: 19':'возраст от 60 до 64 жен',
    'Unnamed: 20':'возраст от 65 до 69 жен',
    'Unnamed: 21':'возраст от 70 до 74 жен',
    'Unnamed: 22':'возраст от 75 до 79 жен',
    'Unnamed: 23':'возраст от 80 до 84 жен',
    'Unnamed: 24':'возраст от 85 жен'})
womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#                 всего жен возраст от 0 до 4 жен возраст от 5 до 9 жен  \
# 1  315376\n403.74\n100.00    621\n16.31\n100.00     374\n8.02\n100.00
# 2         480\n0.61\n0.15         0\n0.00\n0.00         0\n0.00\n0.00
# ...

# %%
womantable11[['всего жен абс', 'всего жен грубый','всего жен уд.']] = womantable11['всего жен'].str.split('\n',expand=True)
final_womantable11 = womantable11.drop('всего жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   возраст от 0 до 4 жен возраст от 5 до 9 жен возраст от 10 до 14 жен  \
# 1    621\n16.31\n100.00     374\n8.02\n100.00       376\n9.16\n100.00
# 2         0\n0.00\n0.00         0\n0.00\n0.00           0\n0.00\n0.00
# ...

# %%
final_womantable11[['возраст от 0 до 4 жен абс', 'возраст от 0 до 4 жен грубый','возраст от 0 до 4 жен уд.']] = final_womantable11['возраст от 0 до 4 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 0 до 4 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   возраст от 5 до 9 жен возраст от 10 до 14 жен возраст от 15 до 19 жен  \
# 1     374\n8.02\n100.00       376\n9.16\n100.00      626\n17.40\n100.00
# 2         0\n0.00\n0.00           0\n0.00\n0.00           0\n0.00\n0.00
# ...

# %%
final_womantable11[['возраст от 5 до 9 жен абс', 'возраст от 5 до 9 жен грубый','возраст от 5 до 9 жен уд.']] = final_womantable11['возраст от 5 до 9 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 5 до 9 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   возраст от 10 до 14 жен возраст от 15 до 19 жен возраст от 20 до 24 жен  \
# 1       376\n9.16\n100.00      626\n17.40\n100.00      858\n25.79\n100.00
# 2           0\n0.00\n0.00           0\n0.00\n0.00           0\n0.00\n0.00
# ...

# %%
final_womantable11[['возраст от 10 до 14 жен абс', 'возраст от 10 до 14 жен грубый','возраст от 10 до 14 жен уд.']] = final_womantable11['возраст от 10 до 14 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 10 до 14 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   возраст от 15 до 19 жен возраст от 20 до 24 жен возраст от 25 до 29 жен  \
# 1      626\n17.40\n100.00      858\n25.79\n100.00     1959\n48.57\n100.00
# 2           0\n0.00\n0.00           0\n0.00\n0.00           1\n0.02\n0.05
# ...

# %%
final_womantable11[['возраст от 15 до 19 жен абс', 'возраст от 15 до 19 жен грубый','возраст от 15 до 19 жен уд.']] = final_womantable11['возраст от 15 до 19 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 15 до 19 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   возраст от 20 до 24 жен возраст от 25 до 29 жен возраст от 30 до 34 жен  \
# 1      858\n25.79\n100.00     1959\n48.57\n100.00     5598\n93.07\n100.00
# 2           0\n0.00\n0.00           1\n0.02\n0.05           0\n0.00\n0.00
# ...

# %%
final_womantable11[['возраст от 20 до 24 жен абс', 'возраст от 20 до 24 жен грубый','возраст от 20 до 24 жен уд.']] = final_womantable11['возраст от 20 до 24 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 20 до 24 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   возраст от 25 до 29 жен возраст от 30 до 34 жен возраст от 35 до 39 жен  \
# 1     1959\n48.57\n100.00     5598\n93.07\n100.00    9900\n159.89\n100.00
# 2           1\n0.02\n0.05           0\n0.00\n0.00           2\n0.03\n0.02
# ...

# %%
final_womantable11[['возраст от 25 до 29 жен абс', 'возраст от 25 до 29 жен грубый','возраст от 25 до 29 жен уд.']] = final_womantable11['возраст от 25 до 29 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 25 до 29 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   возраст от 30 до 34 жен возраст от 35 до 39 жен возраст от 40 до 44 жен  \
# 1     5598\n93.07\n100.00    9900\n159.89\n100.00   14058\n249.37\n100.00
# 2           0\n0.00\n0.00           2\n0.03\n0.02           2\n0.04\n0.01
# ...

# %%
final_womantable11[['возраст от 30 до 34 жен абс', 'возраст от 30 до 34 жен грубый','возраст от 30 до 34 жен уд.']] = final_womantable11['возраст от 30 до 34 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 30 до 34 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   возраст от 35 до 39 жен возраст от 40 до 44 жен возраст от 45 до 49 жен  \
# 1    9900\n159.89\n100.00   14058\n249.37\n100.00   18711\n354.88\n100.00
# 2           2\n0.03\n0.02           2\n0.04\n0.01           1\n0.02\n0.01
# ...

# %%
final_womantable11[['возраст от 35 до 39 жен абс', 'возраст от 35 до 39 жен грубый','возраст от 35 до 39 жен уд.']] = final_womantable11['возраст от 35 до 39 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 35 до 39 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   возраст от 40 до 44 жен возраст от 45 до 49 жен возраст от 50 до 54 жен  \
# 1   14058\n249.37\n100.00   18711\n354.88\n100.00   21621\n455.62\n100.00
# 2           2\n0.04\n0.01           1\n0.02\n0.01           6\n0.13\n0.03
# ...

# %%
final_womantable11[['возраст от 40 до 44 жен абс', 'возраст от 40 до 44 жен грубый','возраст от 40 до 44 жен уд.']] = final_womantable11['возраст от 40 до 44 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 40 до 44 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   возраст от 45 до 49 жен возраст от 50 до 54 жен возраст от 55 до 59 жен  \
# 1   18711\n354.88\n100.00   21621\n455.62\n100.00   31547\n595.31\n100.00
# 2           1\n0.02\n0.01           6\n0.13\n0.03          17\n0.32\n0.05
# ...

# %%
final_womantable11[['возраст от 45 до 49 жен абс', 'возраст от 45 до 49 жен грубый','возраст от 45 до 49 жен уд.']] = final_womantable11['возраст от 45 до 49 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 45 до 49 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   возраст от 50 до 54 жен возраст от 55 до 59 жен возраст от 60 до 64 жен  \
# 1   21621\n455.62\n100.00   31547\n595.31\n100.00   46030\n773.84\n100.00
# 2           6\n0.13\n0.03          17\n0.32\n0.05          33\n0.55\n0.07
# ...

# %%
final_womantable11[['возраст от 50 до 54 жен абс', 'возраст от 50 до 54 жен грубый','возраст от 50 до 54 жен уд.']] = final_womantable11['возраст от 50 до 54 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 50 до 54 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   возраст от 55 до 59 жен возраст от 60 до 64 жен возраст от 65 до 69 жен  \
# 1   31547\n595.31\n100.00   46030\n773.84\n100.00   50289\n959.80\n100.00
# 2          17\n0.32\n0.05          33\n0.55\n0.07          68\n1.30\n0.14
# ...

# %%
final_womantable11[['возраст от 55 до 59 жен абс', 'возраст от 55 до 59 жен грубый','возраст от 55 до 59 жен уд.']] = final_womantable11['возраст от 55 до 59 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 55 до 59 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   возраст от 60 до 64 жен возраст от 65 до 69 жен возраст от 70 до 74 жен  \
# 1   46030\n773.84\n100.00   50289\n959.80\n100.00  46938\n1143.06\n100.00
# 2          33\n0.55\n0.07          68\n1.30\n0.14          62\n1.51\n0.13
# ...

# %%
final_womantable11[['возраст от 60 до 64 жен абс', 'возраст от 60 до 64 жен грубый','возраст от 60 до 64 жен уд.']] = final_womantable11['возраст от 60 до 64 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 60 до 64 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   возраст от 65 до 69 жен возраст от 70 до 74 жен возраст от 75 до 79 жен  \
# 1   50289\n959.80\n100.00  46938\n1143.06\n100.00  21939\n1177.26\n100.00
# 2          68\n1.30\n0.14          62\n1.51\n0.13          68\n3.65\n0.31
# ...

# %%
final_womantable11[['возраст от 65 до 69 жен абс', 'возраст от 65 до 69 жен грубый','возраст от 65 до 69 жен уд.']] = final_womantable11['возраст от 65 до 69 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 65 до 69 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   возраст от 70 до 74 жен возраст от 75 до 79 жен возраст от 80 до 84 жен  \
# 1  46938\n1143.06\n100.00  21939\n1177.26\n100.00  29112\n1111.21\n100.00
# 2          62\n1.51\n0.13          68\n3.65\n0.31         113\n4.31\n0.39
# ...

# %%
final_womantable11[['возраст от 70 до 74 жен абс', 'возраст от 70 до 74 жен грубый','возраст от 70 до 74 жен уд.']] = final_womantable11['возраст от 70 до 74 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 70 до 74 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   возраст от 75 до 79 жен возраст от 80 до 84 жен      возраст от 85 жен  \
# 1  21939\n1177.26\n100.00  29112\n1111.21\n100.00  14819\n902.97\n100.00
# 2          68\n3.65\n0.31         113\n4.31\n0.39        107\n6.52\n0.72
# ...

# %%
final_womantable11[['возраст от 75 до 79 жен абс', 'возраст от 75 до 79 жен грубый','возраст от 75 до 79 жен уд.']] = final_womantable11['возраст от 75 до 79 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 75 до 79 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   возраст от 80 до 84 жен      возраст от 85 жен всего жен абс  \
# 1  29112\n1111.21\n100.00  14819\n902.97\n100.00        315376
# 2         113\n4.31\n0.39        107\n6.52\n0.72           480
# ...

# %%
final_womantable11[['возраст от 80 до 84 жен абс', 'возраст от 80 до 84 жен грубый','возраст от 80 до 84 жен уд.']] = final_womantable11['возраст от 80 до 84 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 80 до 84 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#        возраст от 85 жен всего жен абс всего жен грубый всего жен уд.  \
# 1  14819\n902.97\n100.00        315376           403.74        100.00
# 2        107\n6.52\n0.72           480             0.61          0.15
# ...

# %%
final_womantable11[['возраст от 85 жен абс', 'возраст от 85 жен грубый','возраст от 85 жен уд.']] = final_womantable11['возраст от 85 жен'].str.split('\n',expand=True)
final_womantable11 = final_womantable11.drop('возраст от 85 жен',axis=1)
final_womantable11.head()
# Out:
#                                локализация  код мкб 10  \
# 1  Злокачественные новообразования - всего      С00-96
# 2                                     Губа         С00
# 3                                     Язык      С01.02
# 4                   Большие слюнные железы      С07.08
# 5  Другие и неуточненные части полости рта  C03-06. 09
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                      213.58                                 0.42
# 2                        0.21                                 0.01
# 3                        0.75                                 0.02
# 4                        0.45                                 0.02
# 5                        1.07                                 0.03
#
#   всего жен абс всего жен грубый всего жен уд. возраст от 0 до 4 жен абс  \
# 1        315376           403.74        100.00                       621
# 2           480             0.61          0.15                         0
# ...

# %%
#преобразуем тип данных
final_womantable11.loc[:, 'всего жен абс': 'возраст от 85 жен уд.']=final_womantable11.loc[:, 'всего жен абс': 'возраст от 85 жен уд.'].astype('float')
morbidity_woman=final_womantable11
morbidity_woman.dtypes
# Out:
# локализация                             object
# код мкб 10                              object
# стандартный показатель жен             float64
# ошибочно-стандартный показатель жен    float64
# всего жен абс                          float64
#                                         ...
# возраст от 80 до 84 жен грубый         float64
# возраст от 80 до 84 жен уд.            float64
# возраст от 85 жен абс                  float64
# возраст от 85 жен грубый               float64
# возраст от 85 жен уд.                  float64
# Length: 61, dtype: object

# %% [markdown]
# ## Таблица 66

# %%
mortality_table66 = pd.read_excel('/datasets/2021_Таблица_066.xlsx', header = [3], decimal=',')
mortality_table66 = mortality_table66.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)

# %%
mortality_table66.head()
# Out:
#          Локализация, нозологическая форма  Unnamed: 1 Код МКБ 10  \
# 0                                      NaN         NaN        NaN
# 1  Злокачественные новообразования - всего         NaN     С00-96
# 2                Губа. полость рта. глотка         NaN     С00-14
# 3                                  Пищевод         NaN        С15
# 4                                  Желудок         NaN        С16
#
#    Станд. пока- затель  Ошиб. станд. показ.                  Показа- тель  \
# 0                  NaN                  NaN                           NaN
# 1                99.80                 0.20  Абс.число\n"Грубый" Уд.вес.%
# 2                 3.69                 0.04  Абс.число\n"Грубый" Уд.вес.%
# 3                 2.41                 0.03  Абс.число\n"Грубый" Уд.вес.%
# 4                 8.74                 0.06  Абс.число\n"Грубый" Уд.вес.%
#
#                   Возраст         Unnamed: 7         Unnamed: 8  \
# ...

# %%
mortality_table66.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Локализация, нозологическая форма  28 non-null     object
#  1   Unnamed: 1                         0 non-null      float64
#  2   Код МКБ 10                         28 non-null     object
#  3   Станд. пока- затель                28 non-null     float64
#  4   Ошиб. станд. показ.                28 non-null     float64
#  5   Показа- тель                       28 non-null     object
#  6   Возраст                            29 non-null     object
#  7   Unnamed: 7                         29 non-null     object
#  8   Unnamed: 8                         29 non-null     object
#  9   Unnamed: 9                         29 non-null     object
#  10  Unnamed: 10                        29 non-null     object
# ...

# %%
#и удалим не нужную строку
mortality_table66.drop(labels = [0], axis= 0, inplace= True)
mortality_table66.head()
# Out:
#          Локализация, нозологическая форма  Unnamed: 1 Код МКБ 10  \
# 1  Злокачественные новообразования - всего         NaN     С00-96
# 2                Губа. полость рта. глотка         NaN     С00-14
# 3                                  Пищевод         NaN        С15
# 4                                  Желудок         NaN        С16
# 5                          Тонкий кишечник         NaN        С17
#
#    Станд. пока- затель  Ошиб. станд. показ.                  Показа- тель  \
# 1                99.80                 0.20  Абс.число\n"Грубый" Уд.вес.%
# 2                 3.69                 0.04  Абс.число\n"Грубый" Уд.вес.%
# 3                 2.41                 0.03  Абс.число\n"Грубый" Уд.вес.%
# 4                 8.74                 0.06  Абс.число\n"Грубый" Уд.вес.%
# 5                 0.42                 0.01  Абс.число\n"Грубый" Уд.вес.%
#
#                   Возраст         Unnamed: 7         Unnamed: 8  \
# ...

# %%
#можем удалить столбец
mortality_table66.drop('Unnamed: 1', axis= 1 , inplace= True)
mortality_table66.drop('Показа- тель', axis= 1 , inplace= True)
mortality_table66.head()
# Out:
#          Локализация, нозологическая форма Код МКБ 10  Станд. пока- затель  \
# 1  Злокачественные новообразования - всего     С00-96                99.80
# 2                Губа. полость рта. глотка     С00-14                 3.69
# 3                                  Пищевод        С15                 2.41
# 4                                  Желудок        С16                 8.74
# 5                          Тонкий кишечник        С17                 0.42
#
#    Ошиб. станд. показ.                 Возраст         Unnamed: 7  \
# 1                 0.20  278992\n191.27\n100.00  210\n2.68\n100.00
# 2                 0.04        9223\n6.32\n3.31      0\n0.00\n0.00
# 3                 0.03        6481\n4.44\n2.32      0\n0.00\n0.00
# 4                 0.06      25238\n17.30\n9.05      0\n0.00\n0.00
# 5                 0.01        1195\n0.82\n0.43      1\n0.01\n0.48
#
#           Unnamed: 8         Unnamed: 9        Unnamed: 10        Unnamed: 11  \
# ...

# %%
#переименуем столбцы
mortality_table66 = mortality_table66.rename(
    columns = {
    'Локализация, нозологическая форма':'локализация',
    'Код МКБ 10':'код мкб 10',
    'Станд. пока- затель':'стандартный показатель',
    'Ошиб. станд. показ.':'ошибочно-стандартный показатель',
    'Возраст':'всего',
    'Unnamed: 7':'возраст от 0 до 4',
    'Unnamed: 8':'возраст от 5 до 9',
    'Unnamed: 9':'возраст от 10 до 14',
    'Unnamed: 10':'возраст от 15 до 19',
    'Unnamed: 11':'возраст от 20 до 24',
    'Unnamed: 12':'возраст от 25 до 29',
    'Unnamed: 13':'возраст от 30 до 34',
    'Unnamed: 14':'возраст от 35 до 39',
    'Unnamed: 15':'возраст от 40 до 44',
    'Unnamed: 16':'возраст от 45 до 49',
    'Unnamed: 17':'возраст от 50 до 54',
    'Unnamed: 18':'возраст от 55 до 59',
    'Unnamed: 19':'возраст от 60 до 64',
    'Unnamed: 20':'возраст от 65 до 69',
    'Unnamed: 21':'возраст от 70 до 74',
    'Unnamed: 22':'возраст от 75 до 79',
    'Unnamed: 23':'возраст от 80 до 84',
    'Unnamed: 24':'возраст от 85'})
mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель                   всего  возраст от 0 до 4  \
# 1                             0.20  278992\n191.27\n100.00  210\n2.68\n100.00
# 2                             0.04        9223\n6.32\n3.31      0\n0.00\n0.00
# 3                             0.03        6481\n4.44\n2.32      0\n0.00\n0.00
# 4                             0.06      25238\n17.30\n9.05      0\n0.00\n0.00
# 5                             0.01        1195\n0.82\n0.43      1\n0.01\n0.48
#
# ...

# %%
mortality_table66[['всего абс', 'всего грубый','всего уд.']] = mortality_table66['всего'].str.split('\n',expand=True)
final_mortality_table66 = mortality_table66.drop('всего',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель  возраст от 0 до 4  возраст от 5 до 9  \
# 1                             0.20  210\n2.68\n100.00  267\n2.78\n100.00
# 2                             0.04      0\n0.00\n0.00      1\n0.01\n0.37
# 3                             0.03      0\n0.00\n0.00      0\n0.00\n0.00
# 4                             0.06      0\n0.00\n0.00      1\n0.01\n0.37
# 5                             0.01      1\n0.01\n0.48      0\n0.00\n0.00
#
# ...

# %%
final_mortality_table66[['возраст от 0 до 4 абс', 'возраст от 0 до 4 грубый','возраст от 0 до 4 уд.']] = final_mortality_table66['возраст от 0 до 4'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 0 до 4',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель  возраст от 5 до 9 возраст от 10 до 14  \
# 1                             0.20  267\n2.78\n100.00   232\n2.75\n100.00
# 2                             0.04      1\n0.01\n0.37       1\n0.01\n0.43
# 3                             0.03      0\n0.00\n0.00       1\n0.01\n0.43
# 4                             0.06      1\n0.01\n0.37       0\n0.00\n0.00
# 5                             0.01      0\n0.00\n0.00       0\n0.00\n0.00
#
# ...

# %%
final_mortality_table66[['возраст от 5 до 9 абс', 'возраст от 5 до 9 грубый','возраст от 5 до 9 уд.']] = final_mortality_table66['возраст от 5 до 9'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 5 до 9',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель возраст от 10 до 14 возраст от 15 до 19  \
# 1                             0.20   232\n2.75\n100.00   272\n3.70\n100.00
# 2                             0.04       1\n0.01\n0.43       0\n0.00\n0.00
# 3                             0.03       1\n0.01\n0.43       0\n0.00\n0.00
# 4                             0.06       0\n0.00\n0.00       0\n0.00\n0.00
# 5                             0.01       0\n0.00\n0.00       0\n0.00\n0.00
#
# ...

# %%
final_mortality_table66[['возраст от 10 до 14 абс', 'возраст от 10 до 14 грубый','возраст от 10 до 14 уд.']] = final_mortality_table66['возраст от 10 до 14'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 10 до 14',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель возраст от 15 до 19 возраст от 20 до 24  \
# 1                             0.20   272\n3.70\n100.00   310\n4.58\n100.00
# 2                             0.04       0\n0.00\n0.00       8\n0.12\n2.58
# 3                             0.03       0\n0.00\n0.00       1\n0.01\n0.32
# 4                             0.06       0\n0.00\n0.00       8\n0.12\n2.58
# 5                             0.01       0\n0.00\n0.00       0\n0.00\n0.00
#
# ...

# %%
final_mortality_table66[['возраст от 15 до 19 абс', 'возраст от 15 до 19 грубый','возраст от 15 до 19 уд.']] = final_mortality_table66['возраст от 15 до 19'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 15 до 19',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель возраст от 20 до 24 возраст от 25 до 29  \
# 1                             0.20   310\n4.58\n100.00   589\n7.11\n100.00
# 2                             0.04       8\n0.12\n2.58       9\n0.11\n1.53
# 3                             0.03       1\n0.01\n0.32       4\n0.05\n0.68
# 4                             0.06       8\n0.12\n2.58      41\n0.49\n6.96
# 5                             0.01       0\n0.00\n0.00       4\n0.05\n0.68
#
# ...

# %%
final_mortality_table66[['возраст от 20 до 24 абс', 'возраст от 20 до 24 грубый','возраст от 20 до 24 уд.']] = final_mortality_table66['возраст от 20 до 24'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 20 до 24',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель возраст от 25 до 29  возраст от 30 до 34  \
# 1                             0.20   589\n7.11\n100.00  1679\n13.79\n100.00
# 2                             0.04       9\n0.11\n1.53       35\n0.29\n2.08
# 3                             0.03       4\n0.05\n0.68       15\n0.12\n0.89
# 4                             0.06      41\n0.49\n6.96      120\n0.99\n7.15
# 5                             0.01       4\n0.05\n0.68        9\n0.07\n0.54
#
# ...

# %%
final_mortality_table66[['возраст от 25 до 29 абс', 'возраст от 25 до 29 грубый','возраст от 25 до 29 уд.']] = final_mortality_table66['возраст от 25 до 29'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 25 до 29',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель  возраст от 30 до 34  возраст от 35 до 39  \
# 1                             0.20  1679\n13.79\n100.00  3369\n27.39\n100.00
# 2                             0.04       35\n0.29\n2.08      117\n0.95\n3.47
# 3                             0.03       15\n0.12\n0.89       37\n0.30\n1.10
# 4                             0.06      120\n0.99\n7.15      247\n2.01\n7.33
# 5                             0.01        9\n0.07\n0.54       13\n0.11\n0.39
#
# ...

# %%
final_mortality_table66[['возраст от 30 до 34 абс', 'возраст от 30 до 34 грубый','возраст от 30 до 34 уд.']] = final_mortality_table66['возраст от 30 до 34'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 30 до 34',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель  возраст от 35 до 39  возраст от 40 до 44  \
# 1                             0.20  3369\n27.39\n100.00  5884\n53.64\n100.00
# 2                             0.04      117\n0.95\n3.47      318\n2.90\n5.40
# 3                             0.03       37\n0.30\n1.10       99\n0.90\n1.68
# 4                             0.06      247\n2.01\n7.33      482\n4.39\n8.19
# 5                             0.01       13\n0.11\n0.39       28\n0.26\n0.48
#
# ...

# %%
final_mortality_table66[['возраст от 35 до 39 абс', 'возраст от 35 до 39 грубый','возраст от 35 до 39 уд.']] = final_mortality_table66['возраст от 35 до 39'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 35 до 39',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель  возраст от 40 до 44  возраст от 45 до 49  \
# 1                             0.20  5884\n53.64\n100.00  9805\n97.47\n100.00
# 2                             0.04      318\n2.90\n5.40      676\n6.72\n6.89
# 3                             0.03       99\n0.90\n1.68      281\n2.79\n2.87
# 4                             0.06      482\n4.39\n8.19      762\n7.58\n7.77
# 5                             0.01       28\n0.26\n0.48       37\n0.37\n0.38
#
# ...

# %%
final_mortality_table66[['возраст от 40 до 44 абс', 'возраст от 40 до 44 грубый','возраст от 40 до 44 уд.']] = final_mortality_table66['возраст от 40 до 44'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 40 до 44',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель  возраст от 45 до 49  \
# 1                             0.20  9805\n97.47\n100.00
# 2                             0.04      676\n6.72\n6.89
# 3                             0.03      281\n2.79\n2.87
# 4                             0.06      762\n7.58\n7.77
# 5                             0.01       37\n0.37\n0.38
#
#      возраст от 50 до 54    возраст от 55 до 59    возраст от 60 до 64  \
# 1  14271\n159.73\n100.00  26074\n271.52\n100.00  43230\n419.29\n100.00
# ...

# %%
final_mortality_table66[['возраст от 45 до 49 абс', 'возраст от 45 до 49 грубый','возраст от 45 до 49 уд.']] = final_mortality_table66['возраст от 45 до 49'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 45 до 49',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель    возраст от 50 до 54  \
# 1                             0.20  14271\n159.73\n100.00
# 2                             0.04       919\n10.29\n6.44
# 3                             0.03        435\n4.87\n3.05
# 4                             0.06      1151\n12.88\n8.07
# 5                             0.01         46\n0.51\n0.32
#
#      возраст от 55 до 59    возраст от 60 до 64    возраст от 65 до 69  \
# 1  26074\n271.52\n100.00  43230\n419.29\n100.00  50895\n597.84\n100.00
# ...

# %%
final_mortality_table66[['возраст от 50 до 54 абс', 'возраст от 50 до 54 грубый','возраст от 50 до 54 уд.']] = final_mortality_table66['возраст от 50 до 54'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 50 до 54',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель    возраст от 55 до 59  \
# 1                             0.20  26074\n271.52\n100.00
# 2                             0.04      1334\n13.89\n5.12
# 3                             0.03        835\n8.70\n3.20
# 4                             0.06      2148\n22.37\n8.24
# 5                             0.01        101\n1.05\n0.39
#
#      возраст от 60 до 64    возраст от 65 до 69    возраст от 70 до 74  \
# 1  43230\n419.29\n100.00  50895\n597.84\n100.00  48289\n761.53\n100.00
# ...

# %%
final_mortality_table66[['возраст от 55 до 59 абс', 'возраст от 55 до 59 грубый','возраст от 55 до 59 уд.']] = final_mortality_table66['возраст от 55 до 59'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 55 до 59',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель    возраст от 60 до 64  \
# 1                             0.20  43230\n419.29\n100.00
# 2                             0.04      1872\n18.16\n4.33
# 3                             0.03      1231\n11.94\n2.85
# 4                             0.06      3753\n36.40\n8.68
# 5                             0.01        178\n1.73\n0.41
#
#      возраст от 65 до 69    возраст от 70 до 74    возраст от 75 до 79  \
# 1  50895\n597.84\n100.00  48289\n761.53\n100.00  23036\n854.62\n100.00
# ...

# %%
final_mortality_table66[['возраст от 60 до 64 абс', 'возраст от 60 до 64 грубый','возраст от 60 до 64 уд.']] = final_mortality_table66['возраст от 60 до 64'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 60 до 64',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель    возраст от 65 до 69  \
# 1                             0.20  50895\n597.84\n100.00
# 2                             0.04      1624\n19.08\n3.19
# 3                             0.03      1334\n15.67\n2.62
# 4                             0.06      4680\n54.97\n9.20
# 5                             0.01        198\n2.33\n0.39
#
#      возраст от 70 до 74    возраст от 75 до 79    возраст от 80 до 84  \
# 1  48289\n761.53\n100.00  23036\n854.62\n100.00  31965\n902.63\n100.00
# ...

# %%
final_mortality_table66[['возраст от 65 до 69 абс', 'возраст от 65 до 69 грубый','возраст от 65 до 69 уд.']] = final_mortality_table66['возраст от 65 до 69'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 65 до 69',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель    возраст от 70 до 74  \
# 1                             0.20  48289\n761.53\n100.00
# 2                             0.04      1174\n18.51\n2.43
# 3                             0.03      1072\n16.91\n2.22
# 4                             0.06      4583\n72.28\n9.49
# 5                             0.01        206\n3.25\n0.43
#
#      возраст от 75 до 79    возраст от 80 до 84          возраст от 85  \
# 1  23036\n854.62\n100.00  31965\n902.63\n100.00  18615\n861.30\n100.00
# ...

# %%
final_mortality_table66[['возраст от 70 до 74 абс', 'возраст от 70 до 74 грубый','возраст от 70 до 74 уд.']] = final_mortality_table66['возраст от 70 до 74'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 70 до 74',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель    возраст от 75 до 79  \
# 1                             0.20  23036\n854.62\n100.00
# 2                             0.04       429\n15.92\n1.86
# 3                             0.03       413\n15.32\n1.79
# 4                             0.06      2253\n83.58\n9.78
# 5                             0.01        123\n4.56\n0.53
#
#      возраст от 80 до 84          возраст от 85 всего абс всего грубый  \
# 1  31965\n902.63\n100.00  18615\n861.30\n100.00    278992       191.27
# ...

# %%
final_mortality_table66[['возраст от 75 до 79 абс', 'возраст от 75 до 79 грубый','возраст от 75 до 79 уд.']] = final_mortality_table66['возраст от 75 до 79'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 75 до 79',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель    возраст от 80 до 84  \
# 1                             0.20  31965\n902.63\n100.00
# 2                             0.04       443\n12.51\n1.39
# 3                             0.03       457\n12.90\n1.43
# 4                             0.06     3255\n91.92\n10.18
# 5                             0.01        148\n4.18\n0.46
#
#            возраст от 85 всего абс всего грубый всего уд.  \
# 1  18615\n861.30\n100.00    278992       191.27    100.00
# ...

# %%
final_mortality_table66[['возраст от 80 до 84 абс', 'возраст от 80 до 84 грубый','возраст от 80 до 84 уд.']] = final_mortality_table66['возраст от 80 до 84'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 80 до 84',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель          возраст от 85 всего абс  \
# 1                             0.20  18615\n861.30\n100.00    278992
# 2                             0.04       263\n12.17\n1.41      9223
# 3                             0.03       266\n12.31\n1.43      6481
# 4                             0.06      1754\n81.16\n9.42     25238
# 5                             0.01        103\n4.77\n0.55      1195
#
#   всего грубый всего уд. возраст от 0 до 4 абс возраст от 0 до 4 грубый  ...  \
# ...

# %%
final_mortality_table66[['возраст от 85 абс', 'возраст от 85 грубый','возраст от 85 уд.']] = final_mortality_table66['возраст от 85'].str.split('\n',expand=True)
final_mortality_table66 = final_mortality_table66.drop('возраст от 85',axis=1)
final_mortality_table66.head()
# Out:
#                                локализация код мкб 10  стандартный показатель  \
# 1  Злокачественные новообразования - всего     С00-96                   99.80
# 2                Губа. полость рта. глотка     С00-14                    3.69
# 3                                  Пищевод        С15                    2.41
# 4                                  Желудок        С16                    8.74
# 5                          Тонкий кишечник        С17                    0.42
#
#    ошибочно-стандартный показатель всего абс всего грубый всего уд.  \
# 1                             0.20    278992       191.27    100.00
# 2                             0.04      9223         6.32      3.31
# 3                             0.03      6481         4.44      2.32
# 4                             0.06     25238        17.30      9.05
# 5                             0.01      1195         0.82      0.43
#
#   возраст от 0 до 4 абс возраст от 0 до 4 грубый возраст от 0 до 4 уд.  ...  \
# ...

# %%
#преобразуем тип данных
final_mortality_table66.loc[:, 'всего абс': 'возраст от 85 уд.']=final_mortality_table66.loc[:, 'всего абс': 'возраст от 85 уд.'].astype('float')
mortality_all=final_mortality_table66
mortality_all.dtypes
# Out:
# локализация                         object
# код мкб 10                          object
# стандартный показатель             float64
# ошибочно-стандартный показатель    float64
# всего абс                          float64
#                                     ...
# возраст от 80 до 84 грубый         float64
# возраст от 80 до 84 уд.            float64
# возраст от 85 абс                  float64
# возраст от 85 грубый               float64
# возраст от 85 уд.                  float64
# Length: 61, dtype: object

# %% [markdown]
# ## Таблица 67

# %%
mortality_man_table67 = pd.read_excel('/datasets/2021_Таблица_067.xlsx', header = [3], decimal=',')
mortality_man_table67 = mortality_man_table67.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)
mortality_man_table67.head()
# Out:
#          Локализация, нозологическая форма  Unnamed: 1 Код МКБ 10  \
# 0                                      NaN         NaN        NaN
# 1  Злокачественные новообразования - всего         NaN     С00-96
# 2                Губа. полость рта. глотка         NaN     С00-14
# 3                                  Пищевод         NaN        С15
# 4                                  Желудок         NaN        С16
#
#    Станд. пока- затель  Ошиб. станд. показ.                  Показа- тель  \
# 0                  NaN                  NaN                           NaN
# 1               141.28                 0.37  Абс.число\n"Грубый" Уд.вес.%
# 2                 7.00                 0.08  Абс.число\n"Грубый" Уд.вес.%
# 3                 4.80                 0.07  Абс.число\n"Грубый" Уд.вес.%
# 4                14.05                 0.12  Абс.число\n"Грубый" Уд.вес.%
#
#                   Возраст         Unnamed: 7         Unnamed: 8  \
# ...

# %%
#и удалим не нужную строку и столбцы
mortality_man_table67.drop(labels = [0], axis= 0, inplace= True)
mortality_man_table67.drop('Unnamed: 1', axis= 1 , inplace= True)
mortality_man_table67.drop('Показа- тель', axis= 1 , inplace= True)
mortality_man_table67.head()
# Out:
#          Локализация, нозологическая форма Код МКБ 10  Станд. пока- затель  \
# 1  Злокачественные новообразования - всего     С00-96               141.28
# 2                Губа. полость рта. глотка     С00-14                 7.00
# 3                                  Пищевод        С15                 4.80
# 4                                  Желудок        С16                14.05
# 5                          Тонкий кишечник        С17                 0.56
#
#    Ошиб. станд. показ.                 Возраст         Unnamed: 7  \
# 1                 0.37  149535\n220.71\n100.00  125\n3.10\n100.00
# 2                 0.08       7129\n10.52\n4.77      0\n0.00\n0.00
# 3                 0.07        5040\n7.44\n3.37      0\n0.00\n0.00
# 4                 0.12     15046\n22.21\n10.06      0\n0.00\n0.00
# 5                 0.02         591\n0.87\n0.40      1\n0.02\n0.80
#
#           Unnamed: 8         Unnamed: 9        Unnamed: 10        Unnamed: 11  \
# ...

# %%
#переименуем столбцы
mortality_man_table67 = mortality_man_table67.rename(
    columns = {
    'Локализация, нозологическая форма':'локализация',
    'Код МКБ 10':'код мкб 10',
    'Станд. пока- затель':'стандартный показатель муж',
    'Ошиб. станд. показ.':'ошибочно-стандартный показатель муж',
    'Показа- тель':'показатель муж',
    'Возраст':'всего муж',
    'Unnamed: 7':'возраст от 0 до 4 муж',
    'Unnamed: 8':'возраст от 5 до 9 муж',
    'Unnamed: 9':'возраст от 10 до 14 муж',
    'Unnamed: 10':'возраст от 15 до 19 муж',
    'Unnamed: 11':'возраст от 20 до 24 муж',
    'Unnamed: 12':'возраст от 25 до 29 муж',
    'Unnamed: 13':'возраст от 30 до 34 муж',
    'Unnamed: 14':'возраст от 35 до 39 муж',
    'Unnamed: 15':'возраст от 40 до 44 муж',
    'Unnamed: 16':'возраст от 45 до 49 муж',
    'Unnamed: 17':'возраст от 50 до 54 муж',
    'Unnamed: 18':'возраст от 55 до 59 муж',
    'Unnamed: 19':'возраст от 60 до 64 муж',
    'Unnamed: 20':'возраст от 65 до 69 муж',
    'Unnamed: 21':'возраст от 70 до 74 муж',
    'Unnamed: 22':'возраст от 75 до 79 муж',
    'Unnamed: 23':'возраст от 80 до 84 муж',
    'Unnamed: 24':'возраст от 85 муж'})
mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#                 всего муж возраст от 0 до 4 муж возраст от 5 до 9 муж  \
# 1  149535\n220.71\n100.00     125\n3.10\n100.00     162\n3.29\n100.00
# 2       7129\n10.52\n4.77         0\n0.00\n0.00         0\n0.00\n0.00
# ...

# %%
mortality_man_table67[['всего муж абс', 'всего муж грубый','всего муж уд.']] = mortality_man_table67['всего муж'].str.split('\n',expand=True)
final_mortality_man_table67 = mortality_man_table67.drop('всего муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   возраст от 0 до 4 муж возраст от 5 до 9 муж возраст от 10 до 14 муж  \
# 1     125\n3.10\n100.00     162\n3.29\n100.00       128\n2.96\n100.00
# 2         0\n0.00\n0.00         0\n0.00\n0.00           1\n0.02\n0.78
# ...

# %%
final_mortality_man_table67[['возраст от 0 до 4 муж абс', 'возраст от 0 до 4 муж грубый','возраст от 0 до 4 муж уд.']] = final_mortality_man_table67['возраст от 0 до 4 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 0 до 4 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   возраст от 5 до 9 муж возраст от 10 до 14 муж возраст от 15 до 19 муж  \
# 1     162\n3.29\n100.00       128\n2.96\n100.00       162\n4.32\n100.00
# 2         0\n0.00\n0.00           1\n0.02\n0.78           0\n0.00\n0.00
# ...

# %%
final_mortality_man_table67[['возраст от 5 до 9 муж абс', 'возраст от 5 до 9 муж грубый','возраст от 5 до 9 муж уд.']] = final_mortality_man_table67['возраст от 5 до 9 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 5 до 9 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   возраст от 10 до 14 муж возраст от 15 до 19 муж возраст от 20 до 24 муж  \
# 1       128\n2.96\n100.00       162\n4.32\n100.00       182\n5.28\n100.00
# 2           1\n0.02\n0.78           0\n0.00\n0.00           1\n0.03\n0.55
# ...

# %%
final_mortality_man_table67[['возраст от 10 до 14 муж абс', 'возраст от 10 до 14 муж грубый','возраст от 10 до 14 муж уд.']] = final_mortality_man_table67['возраст от 10 до 14 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 10 до 14 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   возраст от 15 до 19 муж возраст от 20 до 24 муж возраст от 25 до 29 муж  \
# 1       162\n4.32\n100.00       182\n5.28\n100.00       303\n7.13\n100.00
# 2           0\n0.00\n0.00           1\n0.03\n0.55           8\n0.19\n2.64
# ...

# %%
final_mortality_man_table67[['возраст от 15 до 19 муж абс', 'возраст от 15 до 19 муж грубый','возраст от 15 до 19 муж уд.']] = final_mortality_man_table67['возраст от 15 до 19 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 15 до 19 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   возраст от 20 до 24 муж возраст от 25 до 29 муж возраст от 30 до 34 муж  \
# 1       182\n5.28\n100.00       303\n7.13\n100.00      729\n11.84\n100.00
# 2           1\n0.03\n0.55           8\n0.19\n2.64          22\n0.36\n3.02
# ...

# %%
final_mortality_man_table67[['возраст от 20 до 24 муж абс', 'возраст от 20 до 24 муж грубый','возраст от 20 до 24 муж уд.']] = final_mortality_man_table67['возраст от 20 до 24 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 20 до 24 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   возраст от 25 до 29 муж возраст от 30 до 34 муж возраст от 35 до 39 муж  \
# 1       303\n7.13\n100.00      729\n11.84\n100.00     1378\n22.56\n100.00
# 2           8\n0.19\n2.64          22\n0.36\n3.02          88\n1.44\n6.39
# ...

# %%
final_mortality_man_table67[['возраст от 25 до 29 муж абс', 'возраст от 25 до 29 муж грубый','возраст от 25 до 29 муж уд.']] = final_mortality_man_table67['возраст от 25 до 29 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 25 до 29 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   возраст от 30 до 34 муж возраст от 35 до 39 муж возраст от 40 до 44 муж  \
# 1      729\n11.84\n100.00     1378\n22.56\n100.00     2725\n51.12\n100.00
# 2          22\n0.36\n3.02          88\n1.44\n6.39         259\n4.86\n9.50
# ...

# %%
final_mortality_man_table67[['возраст от 30 до 34 муж абс', 'возраст от 30 до 34 муж грубый','возраст от 30 до 34 муж уд.']] = final_mortality_man_table67['возраст от 30 до 34 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 30 до 34 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   возраст от 35 до 39 муж возраст от 40 до 44 муж возраст от 45 до 49 муж  \
# 1     1378\n22.56\n100.00     2725\n51.12\n100.00    5044\n105.37\n100.00
# 2          88\n1.44\n6.39         259\n4.86\n9.50       521\n10.88\n10.33
# ...

# %%
final_mortality_man_table67[['возраст от 35 до 39 муж абс', 'возраст от 35 до 39 муж грубый','возраст от 35 до 39 муж уд.']] = final_mortality_man_table67['возраст от 35 до 39 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 35 до 39 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   возраст от 40 до 44 муж возраст от 45 до 49 муж возраст от 50 до 54 муж  \
# 1     2725\n51.12\n100.00    5044\n105.37\n100.00    8160\n194.81\n100.00
# 2         259\n4.86\n9.50       521\n10.88\n10.33        762\n18.19\n9.34
# ...

# %%
final_mortality_man_table67[['возраст от 40 до 44 муж абс', 'возраст от 40 до 44 муж грубый','возраст от 40 до 44 муж уд.']] = final_mortality_man_table67['возраст от 40 до 44 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 40 до 44 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   возраст от 45 до 49 муж возраст от 50 до 54 муж возраст от 55 до 59 муж  \
# 1    5044\n105.37\n100.00    8160\n194.81\n100.00   15699\n364.78\n100.00
# 2       521\n10.88\n10.33        762\n18.19\n9.34       1083\n25.16\n6.90
# ...

# %%
final_mortality_man_table67[['возраст от 45 до 49 муж абс', 'возраст от 45 до 49 муж грубый','возраст от 45 до 49 муж уд.']] = final_mortality_man_table67['возраст от 45 до 49 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 45 до 49 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   возраст от 50 до 54 муж возраст от 55 до 59 муж возраст от 60 до 64 муж  \
# 1    8160\n194.81\n100.00   15699\n364.78\n100.00   26645\n610.84\n100.00
# 2        762\n18.19\n9.34       1083\n25.16\n6.90       1551\n35.56\n5.82
# ...

# %%
final_mortality_man_table67[['возраст от 50 до 54 муж абс', 'возраст от 50 до 54 муж грубый','возраст от 50 до 54 муж уд.']] = final_mortality_man_table67['возраст от 50 до 54 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 50 до 54 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   возраст от 55 до 59 муж возраст от 60 до 64 муж возраст от 65 до 69 муж  \
# 1   15699\n364.78\n100.00   26645\n610.84\n100.00   30412\n928.99\n100.00
# 2       1083\n25.16\n6.90       1551\n35.56\n5.82       1323\n40.41\n4.35
# ...

# %%
final_mortality_man_table67[['возраст от 55 до 59 муж абс', 'возраст от 55 до 59 муж грубый','возраст от 55 до 59 муж уд.']] = final_mortality_man_table67['возраст от 55 до 59 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 55 до 59 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   возраст от 60 до 64 муж возраст от 65 до 69 муж возраст от 70 до 74 муж  \
# 1   26645\n610.84\n100.00   30412\n928.99\n100.00  27066\n1211.17\n100.00
# 2       1551\n35.56\n5.82       1323\n40.41\n4.35        892\n39.92\n3.30
# ...

# %%
final_mortality_man_table67[['возраст от 60 до 64 муж абс', 'возраст от 60 до 64 муж грубый','возраст от 60 до 64 муж уд.']] = final_mortality_man_table67['возраст от 60 до 64 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 60 до 64 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   возраст от 65 до 69 муж возраст от 70 до 74 муж возраст от 75 до 79 муж  \
# 1   30412\n928.99\n100.00  27066\n1211.17\n100.00  11283\n1356.29\n100.00
# 2       1323\n40.41\n4.35        892\n39.92\n3.30        303\n36.42\n2.69
# ...

# %%
final_mortality_man_table67[['возраст от 65 до 69 муж абс', 'возраст от 65 до 69 муж грубый','возраст от 65 до 69 муж уд.']] = final_mortality_man_table67['возраст от 65 до 69 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 65 до 69 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   возраст от 70 до 74 муж возраст от 75 до 79 муж возраст от 80 до 84 муж  \
# 1  27066\n1211.17\n100.00  11283\n1356.29\n100.00  13199\n1432.41\n100.00
# 2        892\n39.92\n3.30        303\n36.42\n2.69        220\n23.88\n1.67
# ...

# %%
final_mortality_man_table67[['возраст от 70 до 74 муж абс', 'возраст от 70 до 74 муж грубый','возраст от 70 до 74 муж уд.']] = final_mortality_man_table67['возраст от 70 до 74 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 70 до 74 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   возраст от 75 до 79 муж возраст от 80 до 84 муж      возраст от 85 муж  \
# 1  11283\n1356.29\n100.00  13199\n1432.41\n100.00  6133\n1179.13\n100.00
# 2        303\n36.42\n2.69        220\n23.88\n1.67        95\n18.26\n1.55
# ...

# %%
final_mortality_man_table67[['возраст от 75 до 79 муж абс', 'возраст от 75 до 79 муж грубый','возраст от 75 до 79 муж уд.']] = final_mortality_man_table67['возраст от 75 до 79 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 75 до 79 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   возраст от 80 до 84 муж      возраст от 85 муж всего муж абс  \
# 1  13199\n1432.41\n100.00  6133\n1179.13\n100.00        149535
# 2        220\n23.88\n1.67        95\n18.26\n1.55          7129
# ...

# %%
final_mortality_man_table67[['возраст от 80 до 84 муж абс', 'возраст от 80 до 84 муж грубый','возраст от 80 до 84 муж уд.']] = final_mortality_man_table67['возраст от 80 до 84 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 80 до 84 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#        возраст от 85 муж всего муж абс всего муж грубый всего муж уд.  \
# 1  6133\n1179.13\n100.00        149535           220.71        100.00
# 2        95\n18.26\n1.55          7129            10.52          4.77
# ...

# %%
final_mortality_man_table67[['возраст от 85 муж абс', 'возраст от 85 муж грубый','возраст от 85 муж уд.']] = final_mortality_man_table67['возраст от 85 муж'].str.split('\n',expand=True)
final_mortality_man_table67 = final_mortality_man_table67.drop('возраст от 85 муж',axis=1)
final_mortality_man_table67.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель муж  ошибочно-стандартный показатель муж  \
# 1                      141.28                                 0.37
# 2                        7.00                                 0.08
# 3                        4.80                                 0.07
# 4                       14.05                                 0.12
# 5                        0.56                                 0.02
#
#   всего муж абс всего муж грубый всего муж уд. возраст от 0 до 4 муж абс  \
# 1        149535           220.71        100.00                       125
# 2          7129            10.52          4.77                         0
# ...

# %%
#преобразуем тип данных
final_mortality_man_table67.loc[:, 'всего муж абс': 'возраст от 85 муж уд.']=final_mortality_man_table67.loc[:, 'всего муж абс': 'возраст от 85 муж уд.'].astype('float')
mortality_man=final_mortality_man_table67
mortality_man.dtypes
# Out:
# локализация                             object
# код мкб 10                              object
# стандартный показатель муж             float64
# ошибочно-стандартный показатель муж    float64
# всего муж абс                          float64
#                                         ...
# возраст от 80 до 84 муж грубый         float64
# возраст от 80 до 84 муж уд.            float64
# возраст от 85 муж абс                  float64
# возраст от 85 муж грубый               float64
# возраст от 85 муж уд.                  float64
# Length: 61, dtype: object

# %%
mortality_man
# Out:
#                                  локализация     код мкб 10  \
# 1    Злокачественные новообразования - всего         С00-96
# 2                  Губа. полость рта. глотка         С00-14
# 3                                    Пищевод            С15
# 4                                    Желудок            С16
# 5                            Тонкий кишечник            С17
# 6                            Ободочная кишка            С18
# 7   Прямая кишка. ректосиг. соединение. анус         С19-21
# 8        Печень и внутрипеч. желчные протоки            С22
# 9                       Поджелудочная железа            С25
# 10                 Другие органы пищеварения     С23.24. 26
# 11                                   Гортань            С32
# 12                    Трахея. бронхи. легкое         С33.34
# 13    Другие органы дыхания и грудной клетки  С30.31. 37-39
# 14                   Кости и суставные хрящи         С40.41
# 15                             Меланома кожи            С43
# ...

# %% [markdown]
# ## Таблица 68

# %%
mortality_woman_table68 = pd.read_excel('/datasets/2021_Таблица_068.xlsx', header = [3], decimal=',')
mortality_woman_table68 = mortality_woman_table68.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)
mortality_woman_table68.head()
# Out:
#          Локализация, нозологическая форма  Unnamed: 1 Код МКБ 10  \
# 0                                      NaN         NaN        NaN
# 1  Злокачественные новообразования - всего         NaN     С00-96
# 2                Губа. полость рта. глотка         NaN     С00-14
# 3                                  Пищевод         NaN        С15
# 4                                  Желудок         NaN        С16
#
#    Станд. пока- затель  Ошиб. станд. показ.                  Показа- тель  \
# 0                  NaN                  NaN                           NaN
# 1                74.71                 0.23  Абс.число\n"Грубый" Уд.вес.%
# 2                 1.34                 0.03  Абс.число\n"Грубый" Уд.вес.%
# 3                 0.80                 0.02  Абс.число\n"Грубый" Уд.вес.%
# 4                 5.42                 0.06  Абс.число\n"Грубый" Уд.вес.%
#
#                   Возраст        Unnamed: 7         Unnamed: 8  \
# ...

# %%
#и удалим не нужную строку и столбцы
mortality_woman_table68.drop(labels = [0], axis= 0, inplace= True)
mortality_woman_table68.drop('Unnamed: 1', axis= 1 , inplace= True)
mortality_woman_table68.drop('Показа- тель', axis= 1 , inplace= True)
mortality_woman_table68.head()
# Out:
#          Локализация, нозологическая форма Код МКБ 10  Станд. пока- затель  \
# 1  Злокачественные новообразования - всего     С00-96                74.71
# 2                Губа. полость рта. глотка     С00-14                 1.34
# 3                                  Пищевод        С15                 0.80
# 4                                  Желудок        С16                 5.42
# 5                          Тонкий кишечник        С17                 0.33
#
#    Ошиб. станд. показ.                 Возраст        Unnamed: 7  \
# 1                 0.23  129457\n165.73\n100.00  85\n2.23\n100.00
# 2                 0.03        2094\n2.68\n1.62     0\n0.00\n0.00
# 3                 0.02        1441\n1.84\n1.11     0\n0.00\n0.00
# 4                 0.06      10192\n13.05\n7.87     0\n0.00\n0.00
# 5                 0.01         604\n0.77\n0.47     0\n0.00\n0.00
#
#           Unnamed: 8         Unnamed: 9        Unnamed: 10        Unnamed: 11  \
# ...

# %%
#переименуем столбцы
mortality_woman_table68 = mortality_woman_table68.rename(
    columns = {
    'Локализация, нозологическая форма':'локализация',
    'Код МКБ 10':'код мкб 10',
    'Станд. пока- затель':'стандартный показатель жен',
    'Ошиб. станд. показ.':'ошибочно-стандартный показатель жен',
    'Возраст':'всего жен',
    'Unnamed: 7':'возраст от 0 до 4 жен',
    'Unnamed: 8':'возраст от 5 до 9 жен',
    'Unnamed: 9':'возраст от 10 до 14 жен',
    'Unnamed: 10':'возраст от 15 до 19 жен',
    'Unnamed: 11':'возраст от 20 до 24 жен',
    'Unnamed: 12':'возраст от 25 до 29 жен',
    'Unnamed: 13':'возраст от 30 до 34 жен',
    'Unnamed: 14':'возраст от 35 до 39 жен',
    'Unnamed: 15':'возраст от 40 до 44 жен',
    'Unnamed: 16':'возраст от 45 до 49 жен',
    'Unnamed: 17':'возраст от 50 до 54 жен',
    'Unnamed: 18':'возраст от 55 до 59 жен',
    'Unnamed: 19':'возраст от 60 до 64 жен',
    'Unnamed: 20':'возраст от 65 до 69 жен',
    'Unnamed: 21':'возраст от 70 до 74 жен',
    'Unnamed: 22':'возраст от 75 до 79 жен',
    'Unnamed: 23':'возраст от 80 до 84 жен',
    'Unnamed: 24':'возраст от 85 жен'})
mortality_woman_table68.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                       74.71                                 0.23
# 2                        1.34                                 0.03
# 3                        0.80                                 0.02
# 4                        5.42                                 0.06
# 5                        0.33                                 0.01
#
#                 всего жен возраст от 0 до 4 жен возраст от 5 до 9 жен  \
# 1  129457\n165.73\n100.00      85\n2.23\n100.00     105\n2.25\n100.00
# 2        2094\n2.68\n1.62         0\n0.00\n0.00         1\n0.02\n0.95
# ...

# %%
mortality_woman_table68[['всего жен абс', 'всего жен грубый','всего жен уд.']] = mortality_woman_table68['всего жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = mortality_woman_table68.drop('всего жен',axis=1)
final_mortality_woman_table68.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                       74.71                                 0.23
# 2                        1.34                                 0.03
# 3                        0.80                                 0.02
# 4                        5.42                                 0.06
# 5                        0.33                                 0.01
#
#   возраст от 0 до 4 жен возраст от 5 до 9 жен возраст от 10 до 14 жен  \
# 1      85\n2.23\n100.00     105\n2.25\n100.00       104\n2.53\n100.00
# 2         0\n0.00\n0.00         1\n0.02\n0.95           0\n0.00\n0.00
# ...

# %%
final_mortality_woman_table68[['возраст от 0 до 4 жен абс', 'возраст от 0 до 4 жен грубый','возраст от 0 до 4 жен уд.']] = final_mortality_woman_table68['возраст от 0 до 4 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 0 до 4 жен',axis=1)
final_mortality_woman_table68[['возраст от 5 до 9 жен абс', 'возраст от 5 до 9 жен грубый','возраст от 5 до 9 жен уд.']] = final_mortality_woman_table68['возраст от 5 до 9 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 5 до 9 жен',axis=1)
final_mortality_woman_table68[['возраст от 10 до 14 жен абс', 'возраст от 10 до 14 жен грубый','возраст от 10 до 14 жен уд.']] = final_mortality_woman_table68['возраст от 10 до 14 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 10 до 14 жен',axis=1)
final_mortality_woman_table68[['возраст от 15 до 19 жен абс', 'возраст от 15 до 19 жен грубый','возраст от 15 до 19 жен уд.']] = final_mortality_woman_table68['возраст от 15 до 19 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 15 до 19 жен',axis=1)
final_mortality_woman_table68.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                       74.71                                 0.23
# 2                        1.34                                 0.03
# 3                        0.80                                 0.02
# 4                        5.42                                 0.06
# 5                        0.33                                 0.01
#
#   возраст от 20 до 24 жен возраст от 25 до 29 жен возраст от 30 до 34 жен  \
# 1       128\n3.85\n100.00       286\n7.09\n100.00      950\n15.79\n100.00
# 2           7\n0.21\n5.47           1\n0.02\n0.35          13\n0.22\n1.37
# ...

# %%
final_mortality_woman_table68[['возраст от 20 до 24 жен абс', 'возраст от 20 до 24 жен грубый','возраст от 20 до 24 жен уд.']] = final_mortality_woman_table68['возраст от 20 до 24 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 20 до 24 жен',axis=1)
final_mortality_woman_table68[['возраст от 25 до 29 жен абс', 'возраст от 25 до 29 жен грубый','возраст от 25 до 29 жен уд.']] = final_mortality_woman_table68['возраст от 25 до 29 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 25 до 29 жен',axis=1)
final_mortality_woman_table68[['возраст от 30 до 34 жен абс', 'возраст от 30 до 34 жен грубый','возраст от 30 до 34 жен уд.']] = final_mortality_woman_table68['возраст от 30 до 34 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 30 до 34 жен',axis=1)
final_mortality_woman_table68[['возраст от 35 до 39 жен абс', 'возраст от 35 до 39 жен грубый','возраст от 35 до 39 жен уд.']] = final_mortality_woman_table68['возраст от 35 до 39 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 35 до 39 жен',axis=1)
final_mortality_woman_table68[['возраст от 40 до 44 жен абс', 'возраст от 40 до 44 жен грубый','возраст от 40 до 44 жен уд.']] = final_mortality_woman_table68['возраст от 40 до 44 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 40 до 44 жен',axis=1)
final_mortality_woman_table68[['возраст от 45 до 49 жен абс', 'возраст от 45 до 49 жен грубый','возраст от 45 до 49 жен уд.']] = final_mortality_woman_table68['возраст от 45 до 49 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 45 до 49 жен',axis=1)
final_mortality_woman_table68.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                       74.71                                 0.23
# 2                        1.34                                 0.03
# 3                        0.80                                 0.02
# 4                        5.42                                 0.06
# 5                        0.33                                 0.01
#
#   возраст от 50 до 54 жен возраст от 55 до 59 жен возраст от 60 до 64 жен  \
# 1    6111\n128.78\n100.00   10375\n195.78\n100.00   16585\n278.82\n100.00
# 2         157\n3.31\n2.57         251\n4.74\n2.42         321\n5.40\n1.94
# ...

# %%
final_mortality_woman_table68[['возраст от 50 до 54 жен абс', 'возраст от 50 до 54 жен грубый','возраст от 50 до 54 жен уд.']] = final_mortality_woman_table68['возраст от 50 до 54 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 50 до 54 жен',axis=1)
final_mortality_woman_table68[['возраст от 55 до 59 жен абс', 'возраст от 55 до 59 жен грубый','возраст от 55 до 59 жен уд.']] = final_mortality_woman_table68['возраст от 55 до 59 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 55 до 59 жен',axis=1)
final_mortality_woman_table68[['возраст от 60 до 64 жен абс', 'возраст от 60 до 64 жен грубый','возраст от 60 до 64 жен уд.']] = final_mortality_woman_table68['возраст от 60 до 64 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 60 до 64 жен',axis=1)
final_mortality_woman_table68[['возраст от 65 до 69 жен абс', 'возраст от 65 до 69 жен грубый','возраст от 65 до 69 жен уд.']] = final_mortality_woman_table68['возраст от 65 до 69 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 65 до 69 жен',axis=1)
final_mortality_woman_table68[['возраст от 70 до 74 жен абс', 'возраст от 70 до 74 жен грубый','возраст от 70 до 74 жен уд.']] = final_mortality_woman_table68['возраст от 70 до 74 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 70 до 74 жен',axis=1)
final_mortality_woman_table68[['возраст от 75 до 79 жен абс', 'возраст от 75 до 79 жен грубый','возраст от 75 до 79 жен уд.']] = final_mortality_woman_table68['возраст от 75 до 79 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 75 до 79 жен',axis=1)
final_mortality_woman_table68[['возраст от 80 до 84 жен абс', 'возраст от 80 до 84 жен грубый','возраст от 80 до 84 жен уд.']] = final_mortality_woman_table68['возраст от 80 до 84 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 80 до 84 жен',axis=1)
final_mortality_woman_table68[['возраст от 85 жен абс', 'возраст от 85 жен грубый','возраст от 85 жен уд.']] = final_mortality_woman_table68['возраст от 85 жен'].str.split('\n',expand=True)
final_mortality_woman_table68 = final_mortality_woman_table68.drop('возраст от 85 жен',axis=1)
final_mortality_woman_table68.head()
# Out:
#                                локализация код мкб 10  \
# 1  Злокачественные новообразования - всего     С00-96
# 2                Губа. полость рта. глотка     С00-14
# 3                                  Пищевод        С15
# 4                                  Желудок        С16
# 5                          Тонкий кишечник        С17
#
#    стандартный показатель жен  ошибочно-стандартный показатель жен  \
# 1                       74.71                                 0.23
# 2                        1.34                                 0.03
# 3                        0.80                                 0.02
# 4                        5.42                                 0.06
# 5                        0.33                                 0.01
#
#   всего жен абс всего жен грубый всего жен уд. возраст от 0 до 4 жен абс  \
# 1        129457           165.73        100.00                        85
# 2          2094             2.68          1.62                         0
# ...

# %%
#преобразуем тип данных
final_mortality_woman_table68.loc[:, 'всего жен абс': 'возраст от 85 жен уд.']=final_mortality_woman_table68.loc[:, 'всего жен абс': 'возраст от 85 жен уд.'].astype('float')
mortality_woman=final_mortality_woman_table68
mortality_woman.dtypes
# Out:
# локализация                             object
# код мкб 10                              object
# стандартный показатель жен             float64
# ошибочно-стандартный показатель жен    float64
# всего жен абс                          float64
#                                         ...
# возраст от 80 до 84 жен грубый         float64
# возраст от 80 до 84 жен уд.            float64
# возраст от 85 жен абс                  float64
# возраст от 85 жен грубый               float64
# возраст от 85 жен уд.                  float64
# Length: 61, dtype: object

# %%
mortality_woman
# Out:
#                                  локализация     код мкб 10  \
# 1    Злокачественные новообразования - всего         С00-96
# 2                  Губа. полость рта. глотка         С00-14
# 3                                    Пищевод            С15
# 4                                    Желудок            С16
# 5                            Тонкий кишечник            С17
# 6                            Ободочная кишка            С18
# 7   Прямая кишка. ректосиг. соединение. анус         С19-21
# 8        Печень и внутрипеч. желчные протоки            С22
# 9                       Поджелудочная железа            С25
# 10                 Другие органы пищеварения     С23.24. 26
# 11                                   Гортань            С32
# 12                    Трахея. бронхи. легкое         С33.34
# 13    Другие органы дыхания и грудной клетки  С30.31. 37-39
# 14                   Кости и суставные хрящи         С40.41
# 15                             Меланома кожи            С43
# ...

# %% [markdown]
# ## Заболеваемость

# %%
morbidity_all
# Out:
#                                           локализация  \
# 1             Злокачественные новообразования - всего
# 2                                                Губа
# 3                                                Язык
# 4                              Большие слюнные железы
# 5             Другие и неуточненные части полости рта
# 6                                          Ротоглотка
# 7                                          Носоглотка
# 8                                       Гортаноглотка
# 9                                             Пищевод
# 10                                            Желудок
# 11                                    Тонкий кишечник
# 12                                    Ободочная кишка
# 13           Прямая кишка. ректосиг. соединение. анус
# 14                Печень и внутрипеч. желчные протоки
# 15     Желчный пузырь и внепеченочные желчные протоки
# 16                               Поджелудочная железа
# ...

# %%
morbidity_woman
# Out:
#                                           локализация  \
# 1             Злокачественные новообразования - всего
# 2                                                Губа
# 3                                                Язык
# 4                              Большие слюнные железы
# 5             Другие и неуточненные части полости рта
# 6                                          Ротоглотка
# 7                                          Носоглотка
# 8                                       Гортаноглотка
# 9                                             Пищевод
# 10                                            Желудок
# 11                                    Тонкий кишечник
# 12                                    Ободочная кишка
# 13           Прямая кишка. ректосиг. соединение. анус
# 14                Печень и внутрипеч. желчные протоки
# 15     Желчный пузырь и внепеченочные желчные протоки
# 16                               Поджелудочная железа
# ...

# %%
morbidity_man
# Out:
#                                           локализация  \
# 1             Злокачественные новообразования - всего
# 2                                                Губа
# 3                                                Язык
# 4                              Большие слюнные железы
# 5             Другие и неуточненные части полости рта
# 6                                          Ротоглотка
# 7                                          Носоглотка
# 8                                       Гортаноглотка
# 9                                             Пищевод
# 10                                            Желудок
# 11                                    Тонкий кишечник
# 12                                    Ободочная кишка
# 13           Прямая кишка. ректосиг. соединение. анус
# 14                Печень и внутрипеч. желчные протоки
# 15     Желчный пузырь и внепеченочные желчные протоки
# 16                               Поджелудочная железа
# ...

# %% [markdown]
# ## Смертность

# %%
mortality_all
# Out:
#                                  локализация     код мкб 10  \
# 1    Злокачественные новообразования - всего         С00-96
# 2                  Губа. полость рта. глотка         С00-14
# 3                                    Пищевод            С15
# 4                                    Желудок            С16
# 5                            Тонкий кишечник            С17
# 6                            Ободочная кишка            С18
# 7   Прямая кишка. ректосиг. соединение. анус         С19-21
# 8        Печень и внутрипеч. желчные протоки            С22
# 9                       Поджелудочная железа            С25
# 10                 Другие органы пищеварения     С23.24. 26
# 11                                   Гортань            С32
# 12                    Трахея. бронхи. легкое         С33.34
# 13    Другие органы дыхания и грудной клетки  С30.31. 37-39
# 14                   Кости и суставные хрящи         С40.41
# 15                             Меланома кожи            С43
# ...

# %%
mortality_woman
# Out:
#                                  локализация     код мкб 10  \
# 1    Злокачественные новообразования - всего         С00-96
# 2                  Губа. полость рта. глотка         С00-14
# 3                                    Пищевод            С15
# 4                                    Желудок            С16
# 5                            Тонкий кишечник            С17
# 6                            Ободочная кишка            С18
# 7   Прямая кишка. ректосиг. соединение. анус         С19-21
# 8        Печень и внутрипеч. желчные протоки            С22
# 9                       Поджелудочная железа            С25
# 10                 Другие органы пищеварения     С23.24. 26
# 11                                   Гортань            С32
# 12                    Трахея. бронхи. легкое         С33.34
# 13    Другие органы дыхания и грудной клетки  С30.31. 37-39
# 14                   Кости и суставные хрящи         С40.41
# 15                             Меланома кожи            С43
# ...

# %%
mortality_man
# Out:
#                                  локализация     код мкб 10  \
# 1    Злокачественные новообразования - всего         С00-96
# 2                  Губа. полость рта. глотка         С00-14
# 3                                    Пищевод            С15
# 4                                    Желудок            С16
# 5                            Тонкий кишечник            С17
# 6                            Ободочная кишка            С18
# 7   Прямая кишка. ректосиг. соединение. анус         С19-21
# 8        Печень и внутрипеч. желчные протоки            С22
# 9                       Поджелудочная железа            С25
# 10                 Другие органы пищеварения     С23.24. 26
# 11                                   Гортань            С32
# 12                    Трахея. бронхи. легкое         С33.34
# 13    Другие органы дыхания и грудной клетки  С30.31. 37-39
# 14                   Кости и суставные хрящи         С40.41
# 15                             Меланома кожи            С43
# ...

# %%
morbidity_all = morbidity_all.loc[2:39]

# %%
morbidity_woman = morbidity_woman.loc[2:45]

# %%
morbidity_man = morbidity_man.loc[2:42]

# %%
mortality_all = mortality_all.loc[2:28]

# %%
mortality_woman = mortality_woman.loc[2:32]

# %%
mortality_man = mortality_man.loc[2:30]

# %% [markdown]
# ## Файлы для загрузки

# %%
morbidity_all.to_csv('morbidity_all.csv')

# %%
morbidity_woman.to_csv('morbidity_woman.csv')

# %%
morbidity_man.to_csv('morbidity_man.csv')

# %%
mortality_all.to_csv('mortality_all.csv')

# %%
mortality_woman.to_csv('mortality_woman.csv')

# %%
mortality_man.to_csv('mortality_man.csv')

# %% [markdown]
# ## Дашборд

# %% [markdown]
# https://datalens.yandex/csm7yvac454e1
